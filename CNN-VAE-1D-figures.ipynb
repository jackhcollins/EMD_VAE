# %%
import keras
from keras import backend as K
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

from keras.layers import Input, Dense, Activation
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D
from keras.layers import Flatten, Reshape, Lambda
from keras.utils import plot_model
from keras import Model
from keras.models import load_model

import os
import os.path as osp
import sys
sys.path.append('/home/jcollins')

# %% [markdown]
# ### Load data

# %%
import pandas as pd
numjets = 500000
numvalid = 50000
pixels=40

data_dir = "/data1/users/jcollins/Heidelberg_sample"
hdfstore = pd.HDFStore("/data1/users/jcollins/Heidelberg_sample/train_images_4.h5")

valid_data = hdfstore.select("points",start=numjets,stop=numjets+numvalid).values
valid_data = valid_data.reshape(numvalid,pixels,pixels,1)

# %% [markdown]
# ### Define CNN-VAE
#
# Architecture from arXiv:1808.08992, with some small changes and variational component added

# %%
bneck = 1
latent_dim = bneck
image_size = 40 #should be divisible by 4

def sampling(args):
    """Reparameterization trick by sampling fr an isotropic unit Gaussian.

    # Arguments
        args (tensor): mean and log of variance of Q(z|X)

    # Returns
        z (tensor): sampled latent vector
    """

    z_mean, z_log_var = args
    batch = K.shape(z_mean)[0]
    dim = K.int_shape(z_mean)[1]
    # by default, random_normal has mean=0 and std=1.0
    epsilon = K.random_normal(shape=(batch, dim))
    return z_mean + K.exp(0.5 * z_log_var) * epsilon



#Encoder
inputs = Input(shape=(image_size,image_size,1,))
layer = inputs
layer = Conv2D(128, kernel_size=(3,3), activation='relu', padding='same')(layer)
layer = MaxPooling2D(pool_size=(2,2),padding='same')(layer)
layer = Conv2D(128, kernel_size=(3,3), activation='relu', padding='same')(layer)
layer = MaxPooling2D(pool_size=(2,2),padding='same')(layer)
layer = Conv2D(128, kernel_size=(3,3), activation='relu', padding='same')(layer)
layer = Flatten()(layer)
layer = Dense(32,activation='relu')(layer)

#Bottleneck
z_mean = Dense(latent_dim, name='z_mean')(layer)
z_log_var = Dense(latent_dim, name='z_log_var')(layer)
z = Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean, z_log_var])

encoder = Model(inputs, [z_mean, z_log_var, z], name='encoder')
encoder.summary()
#plot_model(encoder, to_file='CNN-VAE_encoder.png', show_shapes=True)

#Decoder
latent_inputs = Input(shape=(latent_dim,), name='z_sampling')

layer = Dense(32,activation='relu')(latent_inputs)
layer = Dense(128*int(image_size*image_size/16),activation='relu')(layer)
layer = Reshape((int(image_size/4),int(image_size/4),128))(layer)
layer = Conv2D(128, kernel_size=(3,3), activation='relu', padding='same')(layer)
layer = UpSampling2D((2,2))(layer)
layer = Conv2D(128, kernel_size=(3,3), activation='relu', padding='same')(layer)
layer = UpSampling2D((2,2))(layer)
layer = Conv2D(1, kernel_size=(3,3), activation='relu', padding='same')(layer)
layer = Reshape((1,image_size*image_size))(layer)
layer = Activation('softmax')(layer)
decoded = Reshape((image_size,image_size,1))(layer)

decoder = Model(latent_inputs, decoded, name='decoder')
decoder.summary()
#plot_model(decoder, to_file='CNN-VAE_decoder.png', show_shapes=True)


outputs = decoder(encoder(inputs)[2])
vae = Model(inputs, outputs, name='CNN-VAE')

def vae_loss(x, x_decoded_mean):
    xent_loss = keras.losses.mean_absolute_error(x, x_decoded_mean)
    kl_loss = - 0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
    kl_loss = K.mean(kl_loss)
    return xent_loss + kl_loss

vae.compile(loss=vae_loss , optimizer=keras.optimizers.Adam())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 40, 40, 1)    0
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 40, 40, 128)  1280        input_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 20, 20, 128)  0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 20, 20, 128)  147584      max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 10, 10, 128)  0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 10, 10, 128)  147584      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 12800)        0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 32)           409632      flatten_4[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 1)            33          dense_10[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 1)            33          dense_10[0][0]
# __________________________________________________________________________________________________
# z (Lambda)                      (None, 1)            0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 706,146
# Trainable params: 706,146
# Non-trainable params: 0
# __________________________________________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# z_sampling (InputLayer)      (None, 1)                 0
# _________________________________________________________________
# dense_11 (Dense)             (None, 32)                64
# _________________________________________________________________
# dense_12 (Dense)             (None, 12800)             422400
# _________________________________________________________________
# reshape_10 (Reshape)         (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 10, 10, 128)       147584
# _________________________________________________________________
# up_sampling2d_7 (UpSampling2 (None, 20, 20, 128)       0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 20, 20, 128)       147584
# _________________________________________________________________
# up_sampling2d_8 (UpSampling2 (None, 40, 40, 128)       0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 40, 40, 1)         1153
# _________________________________________________________________
# reshape_11 (Reshape)         (None, 1, 1600)           0
# _________________________________________________________________
# activation_4 (Activation)    (None, 1, 1600)           0
# _________________________________________________________________
# reshape_12 (Reshape)         (None, 40, 40, 1)         0
# =================================================================
# Total params: 718,785
# Trainable params: 718,785
# Non-trainable params: 0
# _________________________________________________________________

# %%
import glob
output_dir = './data/'
experiment_name = 'CNN-VAE_bneck-1'
epoch = 100
model_file = glob.glob(output_dir + experiment_name + '/model_' + str(epoch) + '*')[0]
vae = load_model(model_file, custom_objects={'vae_loss': vae_loss})

# %%
encoder.set_weights(vae.get_weights())
decoder.set_weights(vae.get_weights()[-10:])

# %% [markdown]
# ### QCD reconstructions

# %%
def chop(array, chop = 1e-5):
    myarray = array
    myarray[array < chop] = 0
    return myarray

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import numpy as np

for i in range(20):
    fig, ax = plt.subplots(1, 2,figsize=[10,5])
    ax[0].imshow(valid_data[i,:,:,0].T, norm=LogNorm(0.01, 1),
               origin='lower',cmap='Oranges')
    ax[1].imshow(chop(vae.predict(valid_data[i:i+1])[0,:,:,0].T,chop=1e-3), norm=LogNorm(0.01, 1),
               origin='lower',cmap='Oranges')
    plt.show()

# %% [markdown]
# ### Top reconstructions

# %%
data_dir = "/data1/users/jcollins/Heidelberg_sample"
hdfstore = pd.HDFStore("/data1/users/jcollins/Heidelberg_sample/train_images_top.h5")
# train_data = hdfstore.select("points",stop=numjets).values
# train_data = train_data.reshape(numjets,pixels,pixels,1)

valid_data_top = hdfstore.select("points",start=numjets,stop=numjets+numvalid).values
valid_data_top = valid_data_top.reshape(numvalid,pixels,pixels,1)

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import numpy as np

for i in range(20):
    fig, ax = plt.subplots(1, 2,figsize=[10,5])
    ax[0].imshow(valid_data_top[i,:,:,0], norm=LogNorm(0.01, 1),
               origin='lower',cmap='Oranges')
    ax[1].imshow(chop(vae.predict(valid_data_top[i:i+1])[0,:,:,0],chop=1e-3), norm=LogNorm(0.01, 1),
               origin='lower',cmap='Oranges')
    plt.show()

# %% [markdown]
# ### 1D latent space visualization
#
# Let's first look at the distribution of latent codes

# %%
latent_codes = encoder.predict(valid_data)[2]

# %%
plt.hist(latent_codes.flatten())
plt.show()

# %%
lim=0.8
bins=np.linspace(-lim, lim, 50)
#codes = np.array([0.45,0.7,1])
codes = np.linspace(-3,3,12)
reconstructions=decoder.predict(codes)

plt.figure(figsize=[15,20])

for i, reconstruction in enumerate(reconstructions):
    plt.subplot(4,3,i+1)
    #counts, bx, by = np.histogram2d(reconstruction[:,0],reconstruction[:,1],bins=bins)
    #print codes[i]
    plt.imshow(chop(reconstruction[:,:,0].T,chop=1e-3), norm=LogNorm(0.01, 1), origin='lower',cmap='Oranges')
    plt.title("code = " + str(codes[i]))
plt.show()
