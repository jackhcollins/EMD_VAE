# %% [markdown]
# # Von Mises Toy

# %% [markdown]
# See if I can implement beta without the big list

# %%
import tensorflow as tf
# config = tf.ConfigProto()
# config.gpu_options.allow_growth = True
# sess = tf.Session(config=config)

import tensorflow.keras as tfk
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Input, Dense, Activation
from tensorflow.keras.layers import Flatten, Reshape, Lambda
from tensorflow.keras.utils import plot_model
from tensorflow.keras import Model
import tensorflow_probability as tfp
tfkl = tfk.layers
tfd = tfp.distributions
tfpl = tfp.layers
import os
import os.path as osp
import sys
sys.path.append('/home/jcollins')

import numpy as np
from scipy import linalg as LA

import matplotlib
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tfkl.concatenate
# Out:
# <function tensorflow.python.keras.layers.merge.concatenate(inputs, axis=-1, **kwargs)>

# %%
def create_dir(dir_path):
    ''' Creates a directory (or nested directories) if they don't exist.
    '''
    if not osp.exists(dir_path):
        os.makedirs(dir_path)

    return dir_path

output_dir = './data/'

# %%
def plot_latent_space_2(encoder, valid_data, xrange = [0.9,1e6]):
    latent_valid = np.array(encoder.predict(valid_data))
    perms = np.argsort(np.mean(latent_valid[1],axis=0))
    latent_valid = latent_valid[:,:,perms]
    
    #print(latent_valid.shape)
    plt.figure(figsize=(10,2.5))
    plt.subplot(1,2,1)
    
    
    
    plt.scatter(np.exp(-np.mean(latent_valid[1,:,:],axis=0)/2),np.sqrt(np.mean(np.square(latent_valid[0,:,:]),axis=0)),s=10.)
    plt.semilogx()
    plt.xlim(xrange)
    plt.ylim([0,1.25])
    plt.ylabel(r'$\sqrt{<\mu^2>}$')
    plt.xlabel(r'$<\sigma>^{-1}$')
    
    plt.subplot(1,2,2)
    
    bins = np.logspace(np.log10(xrange[0]),np.log10(xrange[1]),50)

    plt.hist(np.sqrt(np.mean(np.square(latent_valid[0,:,:20]),axis=0) + np.exp(latent_valid[1,:,:20]))/np.exp(latent_valid[1,:,:20]/2),
         bins=bins,stacked=True)

    plt.xlabel("Inverse resolution")
    plt.semilogx()
    plt.xlim(xrange)
    plt.ylim([0,5e4])





    plt.show()

def plot_latent_space(encoder, valid_data):
    latent_valid = np.array(encoder.predict(valid_data))
    perms = np.argsort(np.mean(latent_valid[1],axis=1))
    latent_valid = latent_valid[:,perms,:]
    plt.figure(figsize=(18,4))

    plt.subplot(1,3,1)
    plt.hist(latent_valid[0,:,0],bins=np.arange(-5,5.00001,0.1),label="latent dimension 1",alpha=0.75)
    plt.hist(latent_valid[0,:,1],bins=np.arange(-5,5.00001,0.1),label="latent dimension 2",alpha=0.75)
    plt.title("latent means")
    plt.xlim([-5,5])
    plt.legend()
    
    plt.subplot(1,3,2)
    bins = np.logspace(-0.1,4,100)
    plt.hist(np.sqrt(np.mean(np.square(latent_valid[0,:,0])) + np.exp(latent_valid[1,:,0]))/np.exp(latent_valid[1,:,0]/2),label="latent dimension 1",alpha=0.75,bins=bins)
    plt.hist(np.sqrt(np.mean(np.square(latent_valid[0,:,1])) + np.exp(latent_valid[1,:,1]))/np.exp(latent_valid[1,:,1]/2),label="latent dimension 2",alpha=0.75,bins=bins)
    plt.title("Inverse resolution")
    plt.semilogx()
    plt.xlim([0.9,1e6])
    plt.legend()



    plt.subplot(1,3,3)
    plt.hist(latent_valid[2,:,0],bins=np.arange(-5,5.00001,0.1),label="latent dimension 1",alpha=0.75)
    plt.hist(latent_valid[2,:,1],bins=np.arange(-5,5.00001,0.1),label="latent dimension 2",alpha=0.75)
    plt.title("sampled z")
    plt.xlim([-5,5])
    plt.legend()

    plt.show()
    
def plot_latent_map(encoder, decoder, train_data_banana,
                    scales = np.array([[-2,2],[-2,2]]),
                    values = np.array([[-1,0,1],[-1,0,1]]),
                    latent_plotrange = [-3,3]):
    
    
    
    scales = np.array(scales)
    values = np.array(values)
    numpoints = 100
    ranges = scales[:,1]-scales[:,0]

    latent_valid_mu, latent_valid_logvar, latent_valid = np.array(encoder.predict(train_data_banana))
    perms = np.argsort(np.mean(latent_valid_logvar,axis=0))
    
    codes1_proj = np.array([np.vstack([np.ones(numpoints)*value,np.linspace(scales[0,0],scales[0,1],numpoints)]).T for value in values[0]])
    codes2_proj = np.array([np.vstack([np.linspace(scales[1,0],scales[1,1],numpoints),np.ones(numpoints)*value]).T for value in values[1]])

    codes1 = np.zeros((3,numpoints,10))
    codes1[:,:,perms[0]] = codes2_proj[:,:,0]
    codes1[:,:,perms[1]] = codes2_proj[:,:,1]
    codes2 = np.zeros((3,numpoints,10))
    codes2[:,:,perms[0]] = codes1_proj[:,:,0]
    codes2[:,:,perms[1]] = codes1_proj[:,:,1]
#     if long_axis == 0:
#         codes0 = np.array([[code,short_values[0]] for code in codes])
#         codes1 = np.array([[code,short_values[1]] for code in codes])
#         codes2 = np.array([[code,short_values[2]] for code in codes])
#     else:
#         codes0 = np.array([[short_values[0],code] for code in codes])
#         codes1 = np.array([[short_values[1],code] for code in codes])
#         codes2 = np.array([[short_values[2],code] for code in codes])

    fig, ax = plt.subplots(1,2,figsize=(12,3.5),gridspec_kw={'width_ratios': [1, 2]})
    

    
    ax[0].scatter(latent_valid[:,perms[0]],latent_valid[:,perms[1]],color='gray',alpha=0.1,s=0.4)
    ax[1].scatter(train_data_banana[:,0],train_data_banana[:,1],color='gray',alpha=0.1,s=0.4)

    cmap = matplotlib.cm.get_cmap('cool')
    
    for i,codes in enumerate(codes1):
#         points = np.zeros((numpoints,2))
        color = cmap(i/3.)
        points = decoder.predict(codes)
        ax[1].plot(points[:,0],points[:,1],color = color)
        ax[0].plot(codes[:,perms[0]],codes[:,perms[1]],color = color)
        
    cmap = matplotlib.cm.get_cmap('autumn')
    
    for i,codes in enumerate(codes2):
        color = cmap(i/3.)
        points = decoder.predict(codes)
        ax[1].plot(points[:,0],points[:,1],color = color)
        ax[0].plot(codes[:,perms[0]],codes[:,perms[1]],color = color)

#     points = np.zeros((int(long_range/0.01),2))
#     points = decoder.predict(codes1)
#     plt.scatter(points[:,0],points[:,1],label=("latent axis " + str(1-long_axis) + " = " + str(short_values[1])),s=0.5)

#     points = np.zeros((int(long_range/0.01),2))
#     points = decoder.predict(codes2)
# #     plt.scatter(points[:,0],points[:,1],label=("latent axis " + str(1-long_axis) + " = " + str(short_values[2])),s=0.5)
#     plt.plot(points[:,0],points[:,1],label=("latent axis " + str(1-long_axis) + " = " + str(short_values[2])))
    ax[1].set_xlim([-2.5,2.5])
    ax[1].set_ylim([-0.75,1.75])
    ax[0].set_xlim(latent_plotrange)
    ax[0].set_ylim(latent_plotrange)
    #plt.legend()

    plt.show()

# %% [markdown]
# ## Generate training data

# %% [markdown]
# Input data is 2D, generated in the shape of a banana (plotted below) defined by two gaussians with widths 1 and 0.1. The VAE will be tasked with reconstructing the 2D location of the input points, using euclidean distance as the reconstruction error. The latent space is 2D, so can in principle easily encode everything about the input. This will be regulated by the variational latent space

# %%
numtrain = 1000000
numvalid = 200000

train_theta = np.random.uniform(-np.pi,np.pi,size=(numtrain))
# train_theta = np.random.normal(size=(numtrain))
train_data = np.zeros((numtrain,2))
train_data[:,0] = np.cos(train_theta)
train_data[:,1] = np.sin(train_theta)

valid_theta = np.random.uniform(-np.pi,np.pi,size=(numvalid))
# valid_theta = np.random.normal(size=(numvalid))
valid_data = np.zeros((numvalid,2))
valid_data[:,0] = np.cos(valid_theta)
valid_data[:,1] = np.sin(valid_theta)



plt.scatter(train_data[:,0],train_data[:,1],s=0.1,alpha=0.1)
plt.xlim([-2,2])
plt.ylim([-2,2])
plt.show()

# %%
plt.hist(valid_theta)
# Out:
# (array([  32.,  167.,  721., 1845., 2715., 2499., 1398.,  513.,  100.,
#           10.]),
#  array([-3.43236404, -2.72262362, -2.01288321, -1.3031428 , -0.59340239,
#          0.11633802,  0.82607843,  1.53581884,  2.24555925,  2.95529966,
#          3.66504007]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### Define VAE

# %%
from utils.build_vae_oneparticle import make_vae_oneparticle

# %%
latent_dims_circle=0
latent_dims_line=4

vae, encoder, decoder = make_vae_oneparticle(loss_type='2D',
                                             real_dim=2,
                                            latent_dims_circle=latent_dims_circle,
                                            latent_dims_line=latent_dims_line)
# Out:
# Model: "model_227"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_153 (InputLayer)          [(None, 2)]          0
# __________________________________________________________________________________________________
# model_225 (Model)               [(None, 4), (None, 4 9032        input_153[0][0]
# __________________________________________________________________________________________________
# input_154 (InputLayer)          [(None, 1)]          0
# __________________________________________________________________________________________________
# model_226 (Model)               (None, 2)            8770        model_225[1][2]
# ==================================================================================================
# Total params: 17,802
# Trainable params: 17,802
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
last_epoch = 0

for beta in np.logspace(-3,2,6)[2:]:
    
    K.set_value(vae.optimizer.lr,1e-4)
    
    print("\n\nSetting beta to ", beta, "\n\n")
    min_delta=1e-6/beta**2
    reduceLR = tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=1, mode='auto', min_delta=min_delta, cooldown=0, min_lr=0)
    earlystop = tfk.callbacks.EarlyStopping(monitor='val_loss', min_delta=min_delta, patience=4, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
    callbacks = [reduceLR,earlystop]

    beta_train = np.ones(len(train_data))*beta
    beta_valid = np.ones(len(valid_data))*beta
    
    history = vae.fit(x=[train_data,beta_train], y=train_data, batch_size=100,
                    epochs=10000,verbose=1,#initial_epoch=history.epoch[-1],
                    validation_data = ([valid_data,beta_valid],valid_data),
                    initial_epoch = last_epoch,
                    callbacks=callbacks
                  )

    last_epoch = history.epoch[-1]


    tfk.models.save_model(vae,"von_mises_linear_beta_" + str(beta) + "_" + str(history.epoch[-1]) + "_model.hdf5")
    vae.save_weights("von_mises_linear_beta_" + str(beta) + "_" + str(history.epoch[-1]) + "_weights.hdf5")
# Out:
# Setting beta to  0.1
#
#
# Train on 100000 samples, validate on 10000 samples
# Epoch 1/10000
# 100000/100000 [==============================] - 6s 55us/sample - loss: 4.3124 - recon_loss: 0.0077 - kl_loss: 3.5393 - val_loss: 4.3717 - val_recon_loss: 0.0090 - val_kl_loss: 3.4684
# Epoch 2/10000
# 100000/100000 [==============================] - 5s 55us/sample - loss: 4.3076 - recon_loss: 0.0077 - kl_loss: 3.5338 - val_loss: 4.3190 - val_recon_loss: 0.0080 - val_kl_loss: 3.5233
# Epoch 3/10000
# 100000/100000 [==============================] - 5s 55us/sample - loss: 4.3289 - recon_loss: 0.0079 - kl_loss: 3.5357 - val_loss: 4.3712 - val_recon_loss: 0.0084 - val_kl_loss: 3.5318
# Epoch 4/10000
#  99400/100000 [============================>.] - ETA: 0s - loss: 4.3068 - recon_loss: 0.0078 - kl_loss: 3.5232
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 100000/100000 [==============================] - 6s 57us/sample - loss: 4.3057 - recon_loss: 0.0078 - kl_loss: 3.5231 - val_loss: 4.3485 - val_recon_loss: 0.0085 - val_kl_loss: 3.5021
# Epoch 5/10000
# 100000/100000 [==============================] - 6s 55us/sample - loss: 4.3014 - recon_loss: 0.0079 - kl_loss: 3.5123 - val_loss: 4.2664 - val_recon_loss: 0.0074 - val_kl_loss: 3.5246
# Epoch 6/10000
# 100000/100000 [==============================] - 6s 55us/sample - loss: 4.2884 - recon_loss: 0.0077 - kl_loss: 3.5161 - val_loss: 4.3194 - val_recon_loss: 0.0081 - val_kl_loss: 3.5098
# Epoch 7/10000
#  99400/100000 [============================>.] - ETA: 0s - loss: 4.2921 - recon_loss: 0.0077 - kl_loss: 3.5171
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 100000/100000 [==============================] - 6s 58us/sample - loss: 4.2932 - recon_loss: 0.0078 - kl_loss: 3.5172 - val_loss: 4.3394 - val_recon_loss: 0.0082 - val_kl_loss: 3.5178
# Epoch 8/10000
# 100000/100000 [==============================] - 6s 57us/sample - loss: 4.2834 - recon_loss: 0.0077 - kl_loss: 3.5174 - val_loss: 4.2320 - val_recon_loss: 0.0072 - val_kl_loss: 3.5167
# Epoch 9/10000
# 100000/100000 [==============================] - 6s 62us/sample - loss: 4.2445 - recon_loss: 0.0073 - kl_loss: 3.5129 - val_loss: 4.3088 - val_recon_loss: 0.0080 - val_kl_loss: 3.5111
# Epoch 10/10000
#  99200/100000 [============================>.] - ETA: 0s - loss: 4.2736 - recon_loss: 0.0076 - kl_loss: 3.5106
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 100000/100000 [==============================] - 6s 60us/sample - loss: 4.2761 - recon_loss: 0.0077 - kl_loss: 3.5106 - val_loss: 4.2362 - val_recon_loss: 0.0072 - val_kl_loss: 3.5118
# Epoch 11/10000
# 100000/100000 [==============================] - 6s 56us/sample - loss: 4.2783 - recon_loss: 0.0077 - kl_loss: 3.5112 - val_loss: 4.2519 - val_recon_loss: 0.0074 - val_kl_loss: 3.5119
# Epoch 12/10000
#  99100/100000 [============================>.] - ETA: 0s - loss: 4.3065 - recon_loss: 0.0080 - kl_loss: 3.5115
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
10000
# 100000/100000 [==============================] - 6s 55us/sample - loss: 0.0100 - recon_loss: 1.0009 - kl_loss: 2.3196e-05 - val_loss: 0.0100 - val_recon_loss: 1.0011 - val_kl_loss: 1.9293e-05
# Epoch 24/10000
# 100000/100000 [==============================] - 6s 56us/sample - loss: 0.0100 - recon_loss: 1.0009 - kl_loss: 1.4857e-05 - val_loss: 0.0100 - val_recon_loss: 1.0009 - val_kl_loss: 1.2383e-05
# Epoch 25/10000
# 100000/100000 [==============================] - 6s 58us/sample - loss: 0.0100 - recon_loss: 1.0009 - kl_loss: 9.8297e-06 - val_loss: 0.0100 - val_recon_loss: 1.0004 - val_kl_loss: 8.8055e-06
# Epoch 26/10000
# 100000/100000 [==============================] - 6s 61us/sample - loss: 0.0100 - recon_loss: 1.0007 - kl_loss: 7.5178e-06 - val_loss: 0.0100 - val_recon_loss: 1.0011 - val_kl_loss: 7.0522e-06
# Epoch 27/10000
#  99100/100000 [============================>.] - ETA: 0s - loss: 0.0100 - recon_loss: 1.0007 - kl_loss: 5.7975e-06
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 100000/100000 [==============================] - 6s 56us/sample - loss: 0.0100 - recon_loss: 1.0007 - kl_loss: 5.7976e-06 - val_loss: 0.0100 - val_recon_loss: 1.0009 - val_kl_loss: 4.5506e-06
# Epoch 28/10000
# 100000/100000 [==============================] - 6s 55us/sample - loss: 0.0100 - recon_loss: 1.0006 - kl_loss: 3.9088e-06 - val_loss: 0.0100 - val_recon_loss: 1.0000 - val_kl_loss: 3.8677e-06
# Epoch 29/10000
# 100000/100000 [==============================] - 6s 57us/sample - loss: 0.0100 - recon_loss: 1.0004 - kl_loss: 3.7926e-06 - val_loss: 0.0100 - val_recon_loss: 1.0005 - val_kl_loss: 3.8292e-06
# Epoch 30/10000
#  47000/100000 [=============>................] - ETA: 2s - loss: 0.0100 - recon_loss: 1.0002 - kl_loss: 3.6929e-06
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-552-5fcb7f2e0192> in <module>
#      18                     validation_data = ([valid_data,beta_valid],valid_data),
#      19                     initial_epoch = last_epoch,
# ---> 20                     callbacks=callbacks
#      21                   )
#      22
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     678         validation_steps=validation_steps,
#     679         validation_freq=validation_freq,
# --> 680         steps_name='steps_per_epoch')
#     681
#     682   def evaluate(self,
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     396
#     397         # Get outputs.
# --> 398         batch_outs = f(ins_batch)
#     399         if not isinstance(batch_outs, list):
#     400           batch_outs = [batch_outs]
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
#last_epoch = 0

for beta in np.logspace(1,-2,7)[2:]:
    
    K.set_value(vae.optimizer.lr,1e-4)
    
    print("\n\nSetting beta to ", beta, "\n\n")
    min_delta=1e-6/beta**2
    reduceLR = tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=1, mode='auto', min_delta=min_delta, cooldown=0, min_lr=0)
    earlystop = tfk.callbacks.EarlyStopping(monitor='val_loss', min_delta=min_delta, patience=4, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
    callbacks = [reduceLR,earlystop]

    beta_train = np.ones(len(train_data))*beta
    beta_valid = np.ones(len(valid_data))*beta
    
    history = vae.fit(x=[train_data,beta_train], y=train_data, batch_size=100,
                    epochs=10000,verbose=1,#initial_epoch=history.epoch[-1],
                    validation_data = ([valid_data,beta_valid],valid_data),
                    initial_epoch = last_epoch,
                    callbacks=callbacks
                  )

    last_epoch = history.epoch[-1]


    tfk.models.save_model(vae,"von_mises_linear_beta_" + str(beta) + "_" + str(history.epoch[-1]) + "_model.hdf5")
    vae.save_weights("von_mises_linear_beta_" + str(beta) + "_" + str(history.epoch[-1]) + "_weights.hdf5")
# Out:
# Setting beta to  1.0
#
#
# Train on 100000 samples, validate on 10000 samples
# Epoch 21/10000
# 100000/100000 [==============================] - 6s 56us/sample - loss: 1.0012 - recon_loss: 0.9973 - kl_loss: 0.0039 - val_loss: 1.0008 - val_recon_loss: 0.9940 - val_kl_loss: 0.0068
# Epoch 22/10000
# 100000/100000 [==============================] - 6s 56us/sample - loss: 1.0010 - recon_loss: 0.9953 - kl_loss: 0.0058 - val_loss: 1.0006 - val_recon_loss: 0.9969 - val_kl_loss: 0.0037
# Epoch 23/10000
# 100000/100000 [==============================] - 6s 56us/sample - loss: 1.0011 - recon_loss: 0.9989 - kl_loss: 0.0022 - val_loss: 1.0013 - val_recon_loss: 1.0002 - val_kl_loss: 0.0012
# Epoch 24/10000
#  99200/100000 [============================>.] - ETA: 0s - loss: 1.0004 - recon_loss: 0.9974 - kl_loss: 0.0030
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 100000/100000 [==============================] - 6s 56us/sample - loss: 1.0004 - recon_loss: 0.9974 - kl_loss: 0.0030 - val_loss: 1.0014 - val_recon_loss: 0.9966 - val_kl_loss: 0.0048
# Epoch 25/10000
# 100000/100000 [==============================] - 6s 56us/sample - loss: 1.0004 - recon_loss: 0.9958 - kl_loss: 0.0047 - val_loss: 1.0010 - val_recon_loss: 0.9965 - val_kl_loss: 0.0045
# Epoch 26/10000
# 100000/100000 [==============================] - 6s 58us/sample - loss: 1.0003 - recon_loss: 0.9960 - kl_loss: 0.0043 - val_loss: 0.9973 - val_recon_loss: 0.9932 - val_kl_loss: 0.0042
# Epoch 27/10000
# 100000/100000 [==============================] - 6s 58us/sample - loss: 1.0006 - recon_loss: 0.9967 - kl_loss: 0.0040 - val_loss: 1.0022 - val_recon_loss: 0.9984 - val_kl_loss: 0.0037
# Epoch 28/10000
#  99800/100000 [============================>.] - ETA: 0s - loss: 1.0004 - recon_loss: 0.9965 - kl_loss: 0.0038
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 100000/100000 [==============================] - 6s 56us/sample - loss: 1.0004 - recon_loss: 0.9965 - kl_loss: 0.0038 - val_loss: 1.0014 - val_recon_loss: 0.9977 - val_kl_loss: 0.0038
# Epoch 29/10000
# 100000/100000 [==============================] - 6s 56us/sample - loss: 1.0005 - recon_loss: 0.9968 - kl_loss: 0.0038 - val_loss: 1.0012 - val_recon_loss: 0.9974 - val_kl_loss: 0.0038
# Epoch 30/10000
#  99000/100000 [============================>.] - ETA: 0s - loss: 1.0005 - recon_loss: 0.9967 - kl_loss: 0.0038
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
10000
# 100000/100000 [==============================] - 6s 56us/sample - loss: 6.2146 - recon_loss: 0.0013 - kl_loss: 4.9002 - val_loss: 6.6823 - val_recon_loss: 0.0018 - val_kl_loss: 4.8613
# Epoch 54/10000
#  99100/100000 [============================>.] - ETA: 0s - loss: 6.3305 - recon_loss: 0.0015 - kl_loss: 4.8596
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 100000/100000 [==============================] - 6s 56us/sample - loss: 6.3310 - recon_loss: 0.0015 - kl_loss: 4.8597 - val_loss: 6.4750 - val_recon_loss: 0.0016 - val_kl_loss: 4.8652
#
#
# Setting beta to  0.01
#
#
# Train on 100000 samples, validate on 10000 samples
# Epoch 54/10000
# 100000/100000 [==============================] - 6s 56us/sample - loss: 8.5883 - recon_loss: 2.3419e-04 - kl_loss: 6.2464 - val_loss: 7.7675 - val_recon_loss: 1.4201e-04 - val_kl_loss: 6.3474
# Epoch 55/10000
# 100000/100000 [==============================] - 6s 57us/sample - loss: 8.3736 - recon_loss: 2.0592e-04 - kl_loss: 6.3143 - val_loss: 7.7468 - val_recon_loss: 1.4455e-04 - val_kl_loss: 6.3013
# Epoch 56/10000
# 100000/100000 [==============================] - 6s 58us/sample - loss: 8.1392 - recon_loss: 1.8267e-04 - kl_loss: 6.3125 - val_loss: 9.6306 - val_recon_loss: 3.4214e-04 - val_kl_loss: 6.2092
# Epoch 57/10000
#  99200/100000 [============================>.] - ETA: 0s - loss: 8.2935 - recon_loss: 2.0136e-04 - kl_loss: 6.2799
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 100000/100000 [==============================] - 6s 55us/sample - loss: 8.2875 - recon_loss: 2.0075e-04 - kl_loss: 6.2800 - val_loss: 8.5985 - val_recon_loss: 2.3007e-04 - val_kl_loss: 6.2978
# Epoch 58/10000
# 100000/100000 [==============================] - 6s 56us/sample - loss: 8.4767 - recon_loss: 2.2113e-04 - kl_loss: 6.2654 - val_loss: 9.9506 - val_recon_loss: 3.7078e-04 - val_kl_loss: 6.2429
# Epoch 59/10000
#  99800/100000 [============================>.] - ETA: 0s - loss: 8.1293 - recon_loss: 1.8836e-04 - kl_loss: 6.2457
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 100000/100000 [==============================] - 6s 56us/sample - loss: 8.1273 - recon_loss: 1.8816e-04 - kl_loss: 6.2457 - val_loss: 9.3866 - val_recon_loss: 3.1493e-04 - val_kl_loss: 6.2372

# %%
#last_epoch = 0

for beta in np.logspace(-2,1,13)[1:]:
    
    K.set_value(vae.optimizer.lr,1e-4)
    
    print("\n\nSetting beta to ", beta, "\n\n")
    min_delta=1e-6/beta**2
    reduceLR = tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=1, mode='auto', min_delta=min_delta, cooldown=0, min_lr=0)
    earlystop = tfk.callbacks.EarlyStopping(monitor='val_loss', min_delta=min_delta, patience=4, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
    callbacks = [reduceLR,earlystop]

    beta_train = np.ones(len(train_data))*beta
    beta_valid = np.ones(len(valid_data))*beta
    
    history = vae.fit(x=[train_data,beta_train], y=train_data, batch_size=100,
                    epochs=10000,verbose=1,#initial_epoch=history.epoch[-1],
                    validation_data = ([valid_data,beta_valid],valid_data),
                    initial_epoch = last_epoch,
                    callbacks=callbacks
                  )

    last_epoch = history.epoch[-1]


    tfk.models.save_model(vae,"von_mises_linear_beta_" + str(beta) + "_" + str(history.epoch[-1]) + "_model.hdf5")
    vae.save_weights("von_mises_linear_beta_" + str(beta) + "_" + str(history.epoch[-1]) + "_weights.hdf5")
# Out:
# Setting beta to  0.01778279410038923
#
#
# Train on 100000 samples, validate on 10000 samples
# Epoch
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# 100000/100000 [==============================] - 5s 53us/sample - loss: 0.3163 - recon_loss: 1.0001 - kl_loss: 2.9133e-05 - val_loss: 0.3163 - val_recon_loss: 1.0002 - val_kl_loss: 2.9060e-05
#
#
# Setting beta to  3.1622776601683795
#
#
# Train on 100000 samples, validate on 10000 samples
# Epoch 126/10000
# 100000/100000 [==============================] - 5s 53us/sample - loss: 0.1001 - recon_loss: 1.0004 - kl_loss: 3.4598e-05 - val_loss: 0.1000 - val_recon_loss: 0.9998 - val_kl_loss: 2.7591e-05
# Epoch 127/10000
# 100000/100000 [==============================] - 5s 54us/sample - loss: 0.1001 - recon_loss: 1.0005 - kl_loss: 2.8298e-05 - val_loss: 0.1001 - val_recon_loss: 1.0005 - val_kl_loss: 2.6279e-05
# Epoch 128/10000
#  99100/100000 [============================>.] - ETA: 0s - loss: 0.1001 - recon_loss: 1.0006 - kl_loss: 2.5578e-05
# Epoch 00128: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 100000/100000 [==============================] - 5s 54us/sample - loss: 0.1001 - recon_loss: 1.0006 - kl_loss: 2.5632e-05 - val_loss: 0.1001 - val_recon_loss: 1.0009 - val_kl_loss: 3.5166e-05
# Epoch 129/10000
# 100000/100000 [==============================] - 6s 55us/sample - loss: 0.1000 - recon_loss: 1.0002 - kl_loss: 1.2738e-05 - val_loss: 0.1000 - val_recon_loss: 1.0001 - val_kl_loss: 1.2577e-05
# Epoch 130/10000
# 100000/100000 [==============================] - 5s 53us/sample - loss: 0.1000 - recon_loss: 1.0002 - kl_loss: 1.2312e-05 - val_loss: 0.1000 - val_recon_loss: 0.9998 - val_kl_loss: 1.3176e-05
# Epoch 131/10000
# 100000/100000 [==============================] - 5s 55us/sample - loss: 0.1000 - recon_loss: 1.0001 - kl_loss: 1.2068e-05 - val_loss: 0.1000 - val_recon_loss: 1.0000 - val_kl_loss: 1.0568e-05
# Epoch 132/10000
#  99300/100000 [============================>.] - ETA: 0s - loss: 0.1000 - recon_loss: 1.0001 - kl_loss: 1.1601e-05
# Epoch 00132: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 100000/100000 [==============================] - 6s 56us/sample - loss: 0.1000 - recon_loss: 1.0001 - kl_loss: 1.1602e-05 - val_loss: 0.1000 - val_recon_loss: 1.0002 - val_kl_loss: 1.1060e-05
# Epoch 133/10000
# 100000/100000 [==============================] - 5s 52us/sample - loss: 0.1000 - recon_loss: 1.0002 - kl_loss: 1.0234e-05 - val_loss: 0.1000 - val_recon_loss: 1.0001 - val_kl_loss: 1.0031e-05
# Epoch 134/10000
#  99200/100000 [============================>.] - ETA: 0s - loss: 0.1000 - recon_loss: 1.0002 - kl_loss: 1.0086e-05
# Epoch 00134: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 100000/100000 [==============================] - 5s 55us/sample - loss: 0.1000 - recon_loss: 1.0002 - kl_loss: 1.0086e-05 - val_loss: 0.1000 - val_recon_loss: 1.0002 - val_kl_loss: 9.9999e-06
#
#
# Setting beta to  5.623413251903491
#
#
# Train on 100000 samples, validate on 10000 samples
# Epoch 134/10000
# 100000/100000 [==============================] - 5s 54us/sample - loss: 0.0316 - recon_loss: 1.0004 - kl_loss: 1.3439e-05 - val_loss: 0.0316 - val_recon_loss: 1.0004 - val_kl_loss: 1.3249e-05
# Epoch 135/10000
# 100000/100000 [==============================] - 5s 53us/sample - loss: 0.0316 - recon_loss: 1.0005 - kl_loss: 1.0166e-05 - val_loss: 0.0316 - val_recon_loss: 1.0003 - val_kl_loss: 8.6319e-06
# Epoch 136/10000
# 100000/100000 [==============================] - 5s 53us/sample - loss: 0.0316 - recon_loss: 1.0005 - kl_loss: 8.2597e-06 - val_loss: 0.0316 - val_recon_loss: 1.0006 - val_kl_loss: 6.6070e-06
# Epoch 137/10000
#  99700/100000 [============================>.] - ETA: 0s - loss: 0.0317 - recon_loss: 1.0006 - kl_loss: 8.0547e-06
# Epoch 00137: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 100000/100000 [==============================] -
10000
# 100000/100000 [==============================] - 5s 54us/sample - loss: 0.0100 - recon_loss: 1.0001 - kl_loss: 1.8052e-06 - val_loss: 0.0100 - val_recon_loss: 1.0002 - val_kl_loss: 1.8013e-06
# Epoch 164/10000
#  99600/100000 [============================>.] - ETA: 0s - loss: 0.0100 - recon_loss: 1.0001 - kl_loss: 1.8039e-06
# Epoch 00164: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# 100000/100000 [==============================] - 5s 52us/sample - loss: 0.0100 - recon_loss: 1.0001 - kl_loss: 1.8042e-06 - val_loss: 0.0100 - val_recon_loss: 1.0002 - val_kl_loss: 1.8017e-06
# Epoch 165/10000
# 100000/100000 [==============================] - 5s 52us/sample - loss: 0.0100 - recon_loss: 1.0001 - kl_loss: 1.8020e-06 - val_loss: 0.0100 - val_recon_loss: 1.0000 - val_kl_loss: 1.8007e-06
# Epoch 166/10000
#  99600/100000 [============================>.] - ETA: 0s - loss: 0.0100 - recon_loss: 1.0000 - kl_loss: 1.8017e-06
# Epoch 00166: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
# 100000/100000 [==============================] - 5s 54us/sample - loss: 0.0100 - recon_loss: 1.0000 - kl_loss: 1.8018e-06 - val_loss: 0.0100 - val_recon_loss: 1.0001 - val_kl_loss: 1.7988e-06

# %%
#last_epoch = 0

for beta in np.logspace(1,-2,16)[1:]:
    
    K.set_value(vae.optimizer.lr,1e-4)
    
    print("\n\nSetting beta to ", beta, "\n\n")
    min_delta=1e-6/beta**2
    reduceLR = tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=1, mode='auto', min_delta=min_delta, cooldown=0, min_lr=0)
    earlystop = tfk.callbacks.EarlyStopping(monitor='val_loss', min_delta=min_delta, patience=4, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
    callbacks = [reduceLR,earlystop]

    beta_train = np.ones(len(train_data))*beta
    beta_valid = np.ones(len(valid_data))*beta
    
    history = vae.fit(x=[train_data,beta_train], y=train_data, batch_size=100,
                    epochs=10000,verbose=1,#initial_epoch=history.epoch[-1],
                    validation_data = ([valid_data,beta_valid],valid_data),
                    initial_epoch = last_epoch,
                    callbacks=callbacks
                  )

    last_epoch = history.epoch[-1]


    tfk.models.save_model(vae,"von_mises_linear_beta_" + str(beta) + "_" + str(history.epoch[-1]) + "_model.hdf5")
    vae.save_weights("von_mises_linear_beta_" + str(beta) + "_" + str(history.epoch[-1]) + "_weights.hdf5")
# Out:
# Setting beta to  6.309573444801933
#
#
# Train on 100000 samples, validate on 10000 samples
# Epoch 166/10000
# 100000/100000 [==============================] - 5s 55us/sample - loss: 0.0252 - recon_loss: 1.0009 - kl_loss: 3.6647e-05 - val_loss: 0.0251 - val_recon_loss: 1.0003 - val_kl_loss: 4.6638e-06
# Epoch 167/10000
# 100000/100000 [==============================] - 6s 57us/sample - loss: 0.0251 - recon_loss: 1.0007 - kl_loss: 3.9268e-06 - val_loss: 0.0251 - val_recon_loss: 1.0006 - val_kl_loss: 3.5958e-06
# Epoch 168/10000
#  99100/100000 [============================>.] - ETA: 0s - loss: 0.0251 - recon_loss: 1.0006 - kl_loss: 3.8263e-06
# Epoch 00168: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 100000/100000 [==============================] - 6s 55us/sample - loss: 0.0251 - recon_loss: 1.0006 - kl_loss: 3.8289e-06 - val_loss: 0.0251 - val_recon_loss: 1.0007 - val_kl_loss: 3.4752e-06
# Epoch 169/10000
# 100000/100000 [==============================] - 6s 55us/sample - loss:
ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 100000/100000 [==============================] - 5s 54us/sample - loss: 8.6631 - recon_loss: 6.9135e-04 - kl_loss: 5.9107 - val_loss: 7.3447 - val_recon_loss: 3.5911e-04 - val_kl_loss: 5.9151
#
#
# Setting beta to  0.01
#
#
# Train on 100000 samples, validate on 10000 samples
# Epoch 268/10000
# 100000/100000 [==============================] - 5s 55us/sample - loss: 10.0486 - recon_loss: 3.5506e-04 - kl_loss: 6.4980 - val_loss: 10.1962 - val_recon_loss: 3.6460e-04 - val_kl_loss: 6.5502
# Epoch 269/10000
# 100000/100000 [==============================] - 6s 56us/sample - loss: 9.5076 - recon_loss: 2.9687e-04 - kl_loss: 6.5389 - val_loss: 8.2374 - val_recon_loss: 1.7157e-04 - val_kl_loss: 6.5217
# Epoch 270/10000
# 100000/100000 [==============================] - 5s 54us/sample - loss: 10.3362 - recon_loss: 3.7945e-04 - kl_loss: 6.5417 - val_loss: 8.4205 - val_recon_loss: 1.8827e-04 - val_kl_loss: 6.5378
# Epoch 271/10000
# 100000/100000 [==============================] - 5s 52us/sample - loss: 9.5020 - recon_loss: 2.9270e-04 - kl_loss: 6.5750 - val_loss: 8.1347 - val_recon_loss: 1.5458e-04 - val_kl_loss: 6.5889
# Epoch 272/10000
# 100000/100000 [==============================] - 5s 53us/sample - loss: 9.8157 - recon_loss: 3.2416e-04 - kl_loss: 6.5742 - val_loss: 8.3006 - val_recon_loss: 1.6903e-04 - val_kl_loss: 6.6102
# Epoch 273/10000
#  99400/100000 [============================>.] - ETA: 0s - loss: 10.0432 - recon_loss: 3.4696e-04 - kl_loss: 6.5736
# Epoch 00273: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 100000/100000 [==============================] - 6s 55us/sample - loss: 10.0361 - recon_loss: 3.4620e-04 - kl_loss: 6.5741 - val_loss: 10.4207 - val_recon_loss: 3.7796e-04 - val_kl_loss: 6.6411
# Epoch 274/10000
# 100000/100000 [==============================] - 5s 53us/sample - loss: 8.6607 - recon_loss: 2.0669e-04 - kl_loss: 6.5937 - val_loss: 9.9009 - val_recon_loss: 3.3551e-04 - val_kl_loss: 6.5459
# Epoch 275/10000
#  99500/100000 [============================>.] - ETA: 0s - loss: 9.8630 - recon_loss: 3.3310e-04 - kl_loss: 6.5320
# Epoch 00275: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 100000/100000 [==============================] - 5s 54us/sample - loss: 9.8518 - recon_loss: 3.3196e-04 - kl_loss: 6.5323 - val_loss: 8.6589 - val_recon_loss: 2.1152e-04 - val_kl_loss: 6.5437

# %%
#last_epoch = 0
#vae.load_weights('von_mises_linear_beta_0.01_274_weights.hdf5')
for beta in np.logspace(-2,-3,5)[1:]:
    
    K.set_value(vae.optimizer.lr,1e-4)
    
    print("\n\nSetting beta to ", beta, "\n\n")
    min_delta=1e-8/beta**2
    reduceLR = tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=1, mode='auto', min_delta=min_delta, cooldown=0, min_lr=0)
    earlystop = tfk.callbacks.EarlyStopping(monitor='val_loss', min_delta=min_delta, patience=4, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
    callbacks = [reduceLR,earlystop]

    beta_train = np.ones(len(train_data))*beta
    beta_valid = np.ones(len(valid_data))*beta
    
    history = vae.fit(x=[train_data,beta_train], y=train_data, batch_size=100,
                    epochs=10000,verbose=1,#initial_epoch=history.epoch[-1],
                    validation_data = ([valid_data,beta_valid],valid_data),
ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
# 100000/100000 [==============================] - 5s 53us/sample - loss: 12.4579 - recon_loss: 2.1073e-06 - kl_loss: 10.3506 - val_loss: 12.4945 - val_recon_loss: 2.1448e-06 - val_kl_loss: 10.3497

# %%
#last_epoch = 0
vae.load_weights('von_mises_linear_upward_0.001_weights.hdf5')
for beta in np.logspace(-3,1,33):
    
    K.set_value(vae.optimizer.lr,1e-4)
    
    print("\n\nSetting beta to ", beta, "\n\n")
    min_delta=1e-8/beta**2
    reduceLR = tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4, verbose=1, mode='auto', min_delta=min_delta, cooldown=0, min_lr=0)
    earlystop = tfk.callbacks.EarlyStopping(monitor='val_loss', min_delta=min_delta, patience=6, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
    callbacks = [reduceLR,earlystop]

    beta_train = np.ones(len(train_data))*beta
    beta_valid = np.ones(len(valid_data))*beta
    
    history = vae.fit(x=[train_data,beta_train], y=train_data, batch_size=1000,
                    epochs=10000,verbose=1,#initial_epoch=history.epoch[-1],
                    validation_data = ([valid_data,beta_valid],valid_data),
                    initial_epoch = last_epoch,
                    callbacks=callbacks
                  )

    last_epoch = history.epoch[-1]


    tfk.models.save_model(vae,"von_mises_linear_upward_" + str(beta) + "_model.hdf5")
    vae.save_weights("von_mises_linear_upward_" + str(beta) + "_weights.hdf5")
# Out:
# Setting beta to  0.001
#
#
# Train on 1000000 samples, validate on 200000 samples
# Epoch 567/10000
# 1000000/1000000 [==============================] - 12s 12us/sample - loss: 19.3731 - recon_loss: 8.7242e-06 - kl_loss: 10.6488 - val_loss: 17.8505 - val_recon_loss: 7.1753e-06 - val_kl_loss: 10.6753
# Epoch 568/10000
# 1000000/1000000 [==============================] - 12s 12us/sample - loss: 19.2138 - recon_loss: 8.5733e-06 - kl_loss: 10.6405 - val_loss: 19.6361 - val_recon_loss: 8.9930e-06 - val_kl_loss: 10.6431
# Epoch 569/10000
# 1000000/1000000 [==============================] - 12s 12us/sample - loss: 19.2302 - recon_loss: 8.6007e-06 - kl_loss: 10.6295 - val_loss: 17.0389 - val_recon_loss: 6.4258e-06 - val_kl_loss: 10.6131
# Epoch 570/10000
# 1000000/1000000 [==============================] - 12s 12us/sample - loss: 19.2308 - recon_loss: 8.6098e-06 - kl_loss: 10.6211 - val_loss: 20.8801 - val_recon_loss: 1.0238e-05 - val_kl_loss: 10.6423
# Epoch 571/10000
# 1000000/1000000 [==============================] - 12s 12us/sample - loss: 19.1557 - recon_loss: 8.5455e-06 - kl_loss: 10.6102 - val_loss: 18.0742 - val_recon_loss: 7.5067e-06 - val_kl_loss: 10.5675
# Epoch 572/10000
# 1000000/1000000 [==============================] - 12s 12us/sample - loss: 19.1320 - recon_loss: 8.5199e-06 - kl_loss: 10.6121 - val_loss: 17.4448 - val_recon_loss: 6.8196e-06 - val_kl_loss: 10.6253
# Epoch 573/10000
#  996000/1000000 [============================>.] - ETA: 0s - loss: 19.0452 - recon_loss: 8.4530e-06 - kl_loss: 10.5922
# Epoch 00573: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 1000000/1000000 [==============================] - 12s 12us/sample - loss: 19.0451 - recon_loss: 8.4529e-06 - kl_loss: 10.5921 - val_loss: 17.5461 - val_recon_loss: 6.9630e-06 - val_kl_loss: 10.5831
# Epoch 574/10000
# 1000000/1000000 [==============================] - 12s 12us/sample - loss: 12.4235 - recon_loss: 1.8532e-06 - kl_loss: 10.5703 - val_loss: 12.2346 - val_recon_loss: 1.6606e-06 - val_kl_loss: 10.5740
# Epoch 575/10000
# 1000000/1000000 [==============================] - 12s 12us/sample - loss: 12.3658 - recon_loss: 1.8037e-06 - kl_loss: 10.5620 - val_loss: 12.3300 - val_recon_loss: 1.7731e-06 - val_kl_loss: 10.5569
# Epoch 576/10000
# 1000000/1000000 [==============================] - 12s 12us/sample - loss: 12.3443 - recon_loss: 1.7998e-06 - kl_loss: 10.5445 - val_loss: 12.4419 - val_recon_loss: 1.8822e-06 - val_kl_loss: 10.5597
# Epoch 577/10000
# 1000000/1000000 [==============================] - 12s 12us/sample - loss:
#        3.16227766e+00, 4.21696503e+00, 5.62341325e+00, 7.49894209e+00,
#        1.00000000e+01])

# %%
np.logspace(-2,-3,5)
# Out:
# array([0.01      , 0.00562341, 0.00316228, 0.00177828, 0.001     ])

# %%
np.logspace(-2,1,16)
# Out:
# array([ 0.01      ,  0.01584893,  0.02511886,  0.03981072,  0.06309573,
#         0.1       ,  0.15848932,  0.25118864,  0.39810717,  0.63095734,
#         1.        ,  1.58489319,  2.51188643,  3.98107171,  6.30957344,
#        10.        ])

# %%
weights_downbeta=['von_mises_linear_beta_10.0_165_weights.hdf5',
                 'von_mises_linear_beta_6.309573444801933_172_weights.hdf5',
                 'von_mises_linear_beta_3.9810717055349722_180_weights.hdf5',
                 'von_mises_linear_beta_2.5118864315095797_187_weights.hdf5',
                 'von_mises_linear_beta_1.5848931924611134_195_weights.hdf5',
                 'von_mises_linear_beta_1.0_203_weights.hdf5',
                 'von_mises_linear_beta_0.630957344480193_210_weights.hdf5',
                 'von_mises_linear_beta_0.39810717055349715_214_weights.hdf5',
                 'von_mises_linear_beta_0.25118864315095796_226_weights.hdf5',
                 'von_mises_linear_beta_0.15848931924611134_237_weights.hdf5',
                 'von_mises_linear_beta_0.1_244_weights.hdf5',
                 'von_mises_linear_beta_0.0630957344480193_252_weights.hdf5',
                 'von_mises_linear_beta_0.03981071705534969_257_weights.hdf5',
                 'von_mises_linear_beta_0.025118864315095794_262_weights.hdf5',
                 'von_mises_linear_beta_0.015848931924611124_267_weights.hdf5',
                 'von_mises_linear_beta_0.01_274_weights.hdf5']
weights_downbeta.reverse()

betas = np.logspace(-2,1,16)

# %%
recon_errors = np.zeros(len(betas))
KL_divs = np.zeros(len(betas))
avg_mus = np.zeros(len(betas))

for i, filename in enumerate(weights_downbeta):
    print(i, 'of', len(weights_downbeta))
    vae.load_weights(filename)
    loss, recon_loss, KL_loss = vae.evaluate([valid_data, np.ones(len(valid_data))*beta],valid_data)
    recon_errors[i] = recon_loss
    KL_divs[i] = KL_loss
    avg_mus[i] = np.sum(np.sqrt(np.mean(np.square(encoder.predict(valid_data)[0]),axis=0)))
# Out:
# 0
# 10000/10000 [==============================] - 1s 58us/sample - loss: 10.6669 - recon_loss: 4.1175e-04 - kl_loss: 6.5438
# 1
# 10000/10000 [==============================] - 1s 58us/sample - loss: 15.6690 - recon_loss: 9.7545e-04 - kl_loss: 5.9152
# 2
# 10000/10000 [==============================] - 1s 72us/sample - loss: 18.9408 - recon_loss: 0.0014 - kl_loss: 5.2304
# 3
# 10000/10000 [==============================] - 1s 68us/sample - loss: 31.2452 - recon_loss: 0.0027 - kl_loss: 4.5912
# 4
# 10000/10000 [==============================] - 1s 56us/sample - loss: 69.9888 - recon_loss: 0.0066 - kl_loss: 4.0053
# 5
# 10000/10000 [==============================] - 1s 65us/sample - loss: 111.1284 - recon_loss: 0.0108 - kl_loss: 3.4330
# 6
# 10000/10000 [==============================] - 1s 59us/sample - loss: 211.2837 - recon_loss: 0.0208 - kl_loss: 2.9028
# 7
# 10000/10000 [==============================] - 1s 57us/sample - loss: 442.6065 - recon_loss: 0.0441 - kl_loss: 2.3449
# 8
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1219.4068 - recon_loss: 0.1218 - kl_loss: 1.6973
# 9
# 10000/10000 [==============================] - 1s 56us/sample - loss: 2946.1607 - recon_loss: 0.2943 - kl_loss: 1.0386
# 10
# 10000/10000 [==============================] - 1s 65us/sample - loss: 9966.3723 - recon_loss: 0.9966 - kl_loss: 0.0037
# 11
# 10000/10000 [==============================] - 1s 55us/sample - loss: 10000.3604 - recon_loss: 1.0000 - kl_loss: 4.9346e-06
# 12
# 10000/10000 [==============================] - 1s 57us/sample - loss: 10002.9382 - recon_loss: 1.0003 - kl_loss: 3.5057e-06
# 13
# 10000/10000 [==============================] - 1s 56us/sample - loss: 10002.2068 - recon_loss: 1.0002 - kl_loss: 1.6036e-06
# 14
# 10000/10000 [==============================] - 1s 55us/sample - loss: 10003.2600 - recon_loss: 1.0003 - kl_loss: 1.5655e-06
# 15
# 10000/10000 [==============================] - 1s 56us/sample - loss: 10001.0951 - recon_loss: 1.0001 - kl_loss: 1.7991e-06

# %%
numsteps = len(betas) - 1

d_betasqr = np.array([betas[i+1]**2 - betas[i]**2 for i in range(numsteps)])
d_log_beta  = np.array([np.log(betas[i+1]/betas[i]) for i in range(numsteps)])
d_recon = np.array([recon_errors[i+1] - recon_errors[i] for i in range(numsteps)])
d_KL = np.array([KL_divs[i+1] - KL_divs[i] for i in range(numsteps)])

# %%
D1_up = 2*d_recon/d_betasqr
D1 = np.array([0.5*(D1_up[i+1] + D1_up[i]) for i in range(len(D1_up)-1)])

# %%
D2_up = -d_KL/d_log_beta
D2 = np.array([0.5*(D2_up[i+1] + D2_up[i]) for i in range(len(D2_up)-1)])

# %%
plt.plot(betas[1:-1],D1)
plt.plot(betas[1:-1],D2)
plt.semilogx()
# Out:
# []

# %%
d_recon
# Out:
# array([ 5.63703041e-04,  4.00078716e-04,  1.28683262e-03,  3.92822642e-03,
#         4.16803313e-03,  1.00766383e-02,  2.32265294e-02,  7.77572319e-02,
#         1.72521800e-01,  7.02267915e-01,  3.42583656e-03,  2.46882439e-04,
#        -6.27040863e-05,  1.05977058e-04, -2.22206116e-04])

# %%
np.sum(np.sqrt(np.mean(np.square(encoder.predict(valid_data)[0]),axis=0)))
# Out:
# 2.7081068

# %%
vae.evaluate([valid_data, np.ones(len(valid_data))*beta],valid_data)
# Out:
# 10000/10000 [==============================] - 1s 58us/sample - loss: 7.8047 - recon_loss: 1.2619e-04 - kl_loss: 6.5438
# [7.804718141174316, 0.00012619405, 6.5438323]

# %%
weights_downbeta
# Out:
# ['von_mises_linear_beta_0.01_274_weights.hdf5',
#  'von_mises_linear_beta_0.015848931924611124_267_weights.hdf5',
#  'von_mises_linear_beta_0.025118864315095794_262_weights.hdf5',
#  'von_mises_linear_beta_0.03981071705534969_257_weights.hdf5',
#  'von_mises_linear_beta_0.0630957344480193_252_weights.hdf5',
#  'von_mises_linear_beta_0.1_244_weights.hdf5',
#  'von_mises_linear_beta_0.15848931924611134_237_weights.hdf5',
#  'von_mises_linear_beta_0.25118864315095796_226_weights.hdf5',
#  'von_mises_linear_beta_0.39810717055349715_214_weights.hdf5',
#  'von_mises_linear_beta_0.630957344480193_210_weights.hdf5',
#  'von_mises_linear_beta_1.0_203_weights.hdf5',
#  'von_mises_linear_beta_1.5848931924611134_195_weights.hdf5',
#  'von_mises_linear_beta_2.5118864315095797_187_weights.hdf5',
#  'von_mises_linear_beta_3.9810717055349722_180_weights.hdf5',
#  'von_mises_linear_beta_6.309573444801933_172_weights.hdf5',
#  'von_mises_linear_beta_10.0_165_weights.hdf5']

# %%
fontsize=16

for dim in range(latent_dims_line):
    plt.scatter(np.arctan2(valid_data[:,0],valid_data[:,1]),encoder.predict(valid_data)[0][:,dim],s=0.1)
plt.xlabel(r"$\theta$",fontsize=fontsize)
plt.ylabel(r"$\mu_\mathrm{latent}$",fontsize=fontsize)
plt.show()

for dim in range(latent_dims_line,latent_dims_circle+latent_dims_line):
    plt.scatter(np.arctan2(valid_data[:,0],valid_data[:,1]),encoder.predict(valid_data)[0][:,dim])
    

plt.show()

for dim in range(latent_dims_line):
    plt.scatter(np.arctan2(valid_data[:,0],valid_data[:,1]),encoder.predict(valid_data)[1][:,dim],s=0.1)
plt.xlabel(r"$\theta$",fontsize=fontsize)
plt.ylabel(r"$\sigma_\mathrm{latent}$",fontsize=fontsize)
plt.show()

for dim in range(latent_dims_line,latent_dims_circle+latent_dims_line):
    plt.scatter(np.arctan2(valid_data[:,0],valid_data[:,1]),encoder.predict(valid_data)[1][:,dim])
plt.show()

# %%
for dim in range(latent_dims_line):
    plt.scatter(valid_theta,encoder.predict(valid_theta)[0][:,dim])
plt.show()

for dim in range(latent_dims_line,latent_dims_circle+latent_dims_line):
    plt.scatter(valid_theta,encoder.predict(valid_theta)[0][:,dim])
plt.show()

for dim in range(latent_dims_line):
    plt.scatter(valid_theta,encoder.predict(valid_theta)[1][:,dim])
plt.show()

for dim in range(latent_dims_line,latent_dims_circle+latent_dims_line):
    plt.scatter(valid_theta,encoder.predict(valid_theta)[1][:,dim])
plt.show()

# %%
plt.scatter(np.arctan2(valid_data[:,0],valid_data[:,1]),encoder.predict(valid_data)[0][:,0])
plt.show()
plt.scatter(np.arctan2(valid_data[:,0],valid_data[:,1]),encoder.predict(valid_data)[0][:,1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-295-78396f6f6a0b> in <module>
# ----> 1 plt.scatter(np.arctan2(valid_data[:,0],valid_data[:,1]),encoder.predict(valid_data)[0][:,0])
#       2 plt.show()
#       3 plt.scatter(np.arctan2(valid_data[:,0],valid_data[:,1]),encoder.predict(valid_data)[0][:,1])
#       4 plt.show()
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1011         max_queue_size=max_queue_size,
#    1012         workers=workers,
# -> 1013         use_multiprocessing=use_multiprocessing)
#    1014
#    1015   def reset_metrics(self):
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_v2.py in predict(self, model, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing, **kwargs)
#     496         model, ModeKeys.PREDICT, x=x, batch_size=batch_size, verbose=verbose,
#     497         steps=steps, callbacks=callbacks, max_queue_size=max_queue_size,
# --> 498         workers=workers, use_multiprocessing=use_multiprocessing, **kwargs)
#     499
#     500
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_v2.py in _model_iteration(self, model, mode, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, **kwargs)
#     424           max_queue_size=max_queue_size,
#     425           workers=workers,
# --> 426           use_multiprocessing=use_multiprocessing)
#     427       total_samples = _get_total_number_of_samples(adapter)
#     428       use_sample = total_samples is not None
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_v2.py in _process_inputs(model, mode, x, y, batch_size, epochs, sample_weights, class_weights, shuffle, steps, distribution_strategy, max_queue_size, workers, use_multiprocessing)
#     644     standardize_function = None
#     645     x, y, sample_weights = standardize(
# --> 646         x, y, sample_weight=sample_weights)
#     647   elif adapter_cls is data_adapter.ListsOfScalarsDataAdapter:
#     648     standardize_function = standardize
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, batch_size, check_steps, steps_name, steps, validation_split, shuffle, extract_tensors_from_dataset)
#    2381         is_dataset=is_dataset,
#    2382         class_weight=class_weight,
# -> 2383         batch_size=batch_size)
#    2384
#    2385   def _standardize_tensors(self, x, y, sample_weight, run_eagerly, dict_inputs,
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training.py in _standardize_tensors(self, x, y, sample_weight, run_eagerly, dict_inputs, is_dataset, class_weight, batch_size)
#    2408           feed_input_shapes,
#    2409           check_batch_axis=False,  # Don't enforce the batch size.
# -> 2410           exception_prefix='input')
#    2411
#    2412     # Get typespecs for the input data and sanitize it if necessary.
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     580                              ': expected ' + names[i] + ' to have shape ' +
#     581                              str(shape) + ' but got array with shape ' +
# --> 582                              str(data_shape))
#     583   return data
#     584
#
# ValueError: Error when checking input: expected input_89 to have shape (1,) but got array with shape (2,)

# %%
plt.scatter(np.arctan2(valid_data[:,0],valid_data[:,1]),encoder.predict([valid_data,beta_valid])[1][:,0])
plt.show()
plt.scatter(np.arctan2(valid_data[:,0],valid_data[:,1]),encoder.predict([valid_data,beta_valid])[1][:,1])
plt.show()

# %%
class encoder_class():
    def __init__(self,encoder):
        self.encoder = encoder
        
    def predict(self, data):
        return self.encoder.predict([data,np.ones(len(data))])

# %% [markdown]
# # Beta-VAE experiments
#
# ## beta = 0.001
# In the limit of small beta, the vae behaves like an AE because the KL term is not given significant weight. It is not to be expected that the latent space directions will be so well behaved.

# %%
experiment_name = '2D_banana'
vae, encoder, decoder = build_and_compile_annealing_vae(encoder = [512,256,128,128],
                                                        decoder = [512,256,128,128],
                                                        optimizer=keras.optimizers.Adam(lr=0.001,clipnorm=0.1))
# Out:
# ---------------------------------------------------------------------------
# OperatorNotAllowedInGraphError            Traceback (most recent call last)
# <ipython-input-70-18c91be02035> in <module>
#       2 vae, encoder, decoder = build_and_compile_annealing_vae(encoder = [512,256,128,128],
#       3                                                         decoder = [512,256,128,128],
# ----> 4                                                         optimizer=keras.optimizers.Adam(lr=0.001,clipnorm=0.1))
#       5
#
# <ipython-input-67-45a07e8b17c5> in build_and_compile_annealing_vae(encoder, decoder, verbose, dropout, optimizer)
#      52     vonmis = tfp.distributions.VonMises(z_mean,tf.exp(z_log_var))
#      53
# ---> 54     z = vonmis.sample()
#      55
#      56     encoder = Model([inputs,beta_input], [z_mean, z_log_var, z], name='encoder')
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_probability/python/distributions/distribution.py in sample(self, sample_shape, seed, name, **kwargs)
#     856       samples: a `Tensor` with prepended dimensions `sample_shape`.
#     857     """
# --> 858     return self._call_sample_n(sample_shape, seed, name, **kwargs)
#     859
#     860   def _call_log_prob(self, value, name, **kwargs):
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_probability/python/distributions/distribution.py in _call_sample_n(self, sample_shape, seed, name, **kwargs)
#     834           sample_shape, 'sample_shape')
#     835       samples = self._sample_n(
# --> 836           n, seed=seed() if callable(seed) else seed, **kwargs)
#     837       batch_event_shape = tf.shape(samples)[1:]
#     838       final_shape = tf.concat([sample_shape, batch_event_shape], 0)
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_probability/python/distributions/von_mises.py in _sample_n(self, n, seed)
#     264         [n], prefer_static.shape(concentration)], axis=0)
#     265     samples = random_von_mises(
# --> 266         sample_batch_shape, concentration, dtype=self.dtype, seed=seed)
#     267
#     268     # vonMises(0, concentration) -> vonMises(loc, concentration)
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_probability/python/distributions/von_mises.py in random_von_mises(shape, concentration, dtype, seed)
#     629     return x, grad
#     630
# --> 631   return rejection_sample_with_gradient(concentration)
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/ops/custom_gradient.py in __call__(self, *a, **k)
#     254
#     255   def __call__(self, *a, **k):
# --> 256     return self._d(self._f, a, k)
#     257
#     258
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/ops/custom_gradient.py in decorated(wrapped, args, kwargs)
#     208     """Decorated function with custom gradient."""
#     209     if context.executing_eagerly():
# --> 210       return _eager_mode_decorator(wrapped, args, kwargs)
#     211     else:
#     212       return _graph_mode_decorator(wrapped, args, kwargs)
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/ops/custom_gradient.py in _eager_mode_decorator(f, args, kwargs)
#     404   """Implement custom gradient decorator for eager mode."""
#     405   with backprop.GradientTape() as tape:
# --> 406     result, grad_fn = f(*args, **kwargs)
#     407   all_inputs = list(args) + list(kwargs.values())
#     408   # The variables that grad_fn needs to return gradients for are the set of
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_probability/python/distributions/von_mises.py in rejection_sample_with_gradient(concentration)
#     605         # for very large / nan concentration.
#     606         maximum_iterations=100,
# --> 607         parallel_iterations=1 if seed.original_seed is None else 10,
#     608     )
#     609
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/ops/control_flow_ops.py in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#    2476       name=name,
#    2477       maximum_iterations=maximum_iterations,
# -> 2478       return_same_structure=True)
#    2479
#    2480
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/ops/control_flow_ops.py in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    2711       loop_var_structure = nest.map_structure(type_spec.type_spec_from_value,
#    2712                                               list(loop_vars))
# -> 2713       while cond(*loop_vars):
#    2714         loop_vars = body(*loop_vars)
#    2715         if try_to_pack and not isinstance(loop_vars, (list, _basetuple)):
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/framework/ops.py in __bool__(self)
#     755       `TypeError`.
#     756     """
# --> 757     self._disallow_bool_casting()
#     758
#     759   def __nonzero__(self):
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/framework/ops.py in _disallow_bool_casting(self)
#     524     else:
#     525       # Default: V1-style Graph execution.
# --> 526       self._disallow_in_graph_mode("using a `tf.Tensor` as a Python `bool`")
#     527
#     528   def _disallow_iteration(self):
#
# ~/venvs/tf2/lib/python3.6/site-packages/tensorflow_core/python/framework/ops.py in _disallow_in_graph_mode(self, task)
#     513     raise errors.OperatorNotAllowedInGraphError(
#     514         "{} is not allowed in Graph execution. Use Eager execution or decorate"
# --> 515         " this function with @tf.function.".format(task))
#     516
#     517   def _disallow_bool_casting(self):
#
# OperatorNotAllowedInGraphError: using a `tf.Tensor` as a Python `bool` is not allowed in Graph execution. Use Eager execution or decorate this function with @tf.function.

# %%
reduceLR = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=1, mode='auto', min_delta=1e-5, cooldown=0, min_lr=0)
earlystop = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1e-5, patience=3, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
callbacks = [modelcheckpoint,reduceLR,earlystop]

beta = 0.3
K.set_value(vae.optimizer.lr,1e-4)
epochs = 1000
history = vae.fit(x=[train_data,np.ones(len(train_data))*beta], y=train_data, batch_size=100,
                epochs=epochs,verbose=1,#initial_epoch=history.epoch[-1],
                validation_data = ([valid_data,np.ones(len(valid_data))*beta],valid_data),
                callbacks = callbacks
              )

# tf.saved_model.save(vae, train_output_dir + '/mymodel.hdf5')
# Out:
# Train on 100000 samples, validate on 10000 samples
# Epoch 1/1000
# 100000/100000 [==============================] - 8s 78us/sample - loss: 2.2979 - recon_loss: 0.0564 - get_kl_loss: 1.6718 - val_loss: 2.2188 - val_recon_loss: 0.0602 - val_get_kl_loss: 1.5503
# Epoch 2/1000
# 100000/100000 [==============================] - 7s 73us/sample - loss: 2.2268 - recon_loss: 0.0578 - get_kl_loss: 1.5846 - val_loss: 2.2099 - val_recon_loss: 0.0548 - val_get_kl_loss: 1.6010
# Epoch 3/1000
# 100000/100000 [==============================] - 9s 91us/sample - loss: 2.2178 - recon_loss: 0.0574 - get_kl_loss: 1.5803 - val_loss: 2.2785 - val_recon_loss: 0.0657 - val_get_kl_loss: 1.5483
# Epoch 4/1000
# 100000/100000 [==============================] - 12s 121us/sample - loss: 2.2160 - recon_loss: 0.0570 - get_kl_loss: 1.5823 - val_loss: 2.2036 - val_recon_loss: 0.0566 - val_get_kl_loss: 1.5752
# Epoch 5/1000
# 100000/100000 [==============================] - 9s 87us/sample - loss: 2.2190 - recon_loss: 0.0571 - get_kl_loss: 1.5850 - val_loss: 2.1976 - val_recon_loss: 0.0537 - val_get_kl_loss: 1.6004
# Epoch 6/1000
# 100000/100000 [==============================] - 8s 81us/sample - loss: 2.2180 - recon_loss: 0.0572 - get_kl_loss: 1.5822 - val_loss: 2.2342 - val_recon_loss: 0.0583 - val_get_kl_loss: 1.5862
# Epoch 7/1000
# 100000/100000 [==============================] - 7s 75us/sample - loss: 2.2140 - recon_loss: 0.0570 - get_kl_loss: 1.5803 - val_loss: 2.1929 - val_recon_loss: 0.0539 - val_get_kl_loss: 1.5944
# Epoch 8/1000
# 100000/100000 [==============================] - 7s 75us/sample - loss: 2.2169 - recon_loss: 0.0569 - get_kl_loss: 1.5852 - val_loss: 2.2013 - val_recon_loss: 0.0555 - val_get_kl_loss: 1.5847
# Epoch 9/1000
#  99300/100000 [============================>.] - ETA: 0s - loss: 2.2105 - recon_loss: 0.0566 - get_kl_loss: 1.5815
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 100000/100000 [==============================] - 8s 75us/sample - loss: 2.2103 - recon_loss: 0.0566 - get_kl_loss: 1.5812 - val_loss: 2.1934 - val_recon_loss: 0.0538 - val_get_kl_loss: 1.5955
# Epoch 10/1000
# 100000/100000 [==============================] - 7s 74us/sample - loss: 2.1989 - recon_loss: 0.0551 - get_kl_loss: 1.5865 - val_loss: 2.1818 - val_recon_loss: 0.0551 - val_get_kl_loss: 1.5700
# Epoch 11/1000
# 100000/100000 [==============================] - 7s 75us/sample - loss: 2.1935 - recon_loss: 0.0552 - get_kl_loss: 1.5806 - val_loss: 2.1829 - val_recon_loss: 0.0540 - val_get_kl_loss: 1.5825
# Epoch 12/1000
#  99300/100000 [============================>.] - ETA: 0s - loss: 2.1963 - recon_loss: 0.0553 - get_kl_loss: 1.5822
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 100000/100000 [==============================] - 8s 75us/sample - loss: 2.1959 - recon_loss: 0.0552 - get_kl_loss: 1.5824 - val_loss: 2.1935 - val_recon_loss: 0.0544 - val_get_kl_loss: 1.5893
# Epoch 13/1000
# 100000/100000 [==============================] - 8s 81us/sample - loss: 2.1892 - recon_loss: 0.0545 - get_kl_loss: 1.5835 - val_loss: 2.1890 - val_recon_loss: 0.0555 - val_get_kl_loss: 1.5725

# %%
print("Latent space encoding for beta =",beta,":")
myencoder = encoder_class(encoder)
    
plot_latent_space_2(myencoder,valid_data,xrange = [0.9,1e2])
# Out:
# Latent space encoding for beta = 3.0 :

# %% [markdown]
# We see from the rightmost plot especially that the latent space is not well regulated. There doesn't seem to be much useful information in the middle plot.

# %%
plot_latent_map(myencoder, decoder, valid_data)

# %%
betas = np.array([1e-2,3e-2,6e-2,8e-2,9e-2,1e-1,1.1e-1,1.2e-1,1.4e-1,2e-1,4e-1,6e-1,8e-1,9e-1,1.,1.1,1.2,1.4,1.6,2.,4.])
sigmas = np.zeros(len(betas))
KLs = np.zeros(len(betas))

# %%
for i, beta in enumerate(betas[:3]):
    min_delta=1e-6/beta**2
    reduceLR = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=1, mode='auto', min_delta=min_delta, cooldown=0, min_lr=0)
    earlystop = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=min_delta, patience=4, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
    callbacks = [modelcheckpoint,reduceLR,earlystop]

    K.set_value(vae.optimizer.lr,1e-5)
    epochs = 1000
    history = vae.fit(x=[train_data,np.ones(len(train_data))*beta], y=train_data, batch_size=100,
                    epochs=epochs,verbose=1,#initial_epoch=history.epoch[-1],
                    validation_data = ([valid_data,np.ones(len(valid_data))*beta],valid_data),
                    callbacks = callbacks
                  )
    
    KLs[i] = history.history['val_get_kl_loss'][-1]    
    sigmas[i] = history.history['val_recon_loss'][-1]
    
    print("Latent space encoding for beta =",beta,":")
    myencoder = encoder_class(encoder)

    plot_latent_space_2(myencoder,valid_data,xrange = [0.9,1e4])
# Out:
# Train on 100000 samples, validate on 10000 samples
# Epoch 1/1000
# 100000/100000 [==============================] - 9s 85us/sample - loss: 138.3060 - recon_loss: 0.0134 - get_kl_loss: 3.9972 - val_loss: 99.3005 - val_recon_loss: 0.0094 - val_get_kl_loss: 5.0434
# Epoch 2/1000
# 100000/100000 [==============================] - 8s 76us/sample - loss: 96.3089 - recon_loss: 0.0091 - get_kl_loss: 5.4253 - val_loss: 84.1056 - val_recon_loss: 0.0078 - val_get_kl_loss: 6.0385
# Epoch 3/1000
# 100000/100000 [==============================] - 8s 80us/sample - loss: 28.3191 - recon_loss: 0.0021 - get_kl_loss: 7.6697 - val_loss: 10.6487 - val_recon_loss: 2.1974e-04 - val_get_kl_loss: 8.4512
# Epoch 4/1000
# 100000/100000 [==============================] - 7s 75us/sample - loss: 10.1209 - recon_loss: 1.8333e-04 - get_kl_loss: 8.2876 - val_loss: 9.8067 - val_recon_loss: 1.6613e-04 - val_get_kl_loss: 8.1454
# Epoch 5/1000
# 100000/100000 [==============================] - 7s 74us/sample - loss: 9.7883 - recon_loss: 1.6483e-04 - get_kl_loss: 8.1400 - val_loss: 9.6260 - val_recon_loss: 1.5096e-04 - val_get_kl_loss: 8.1164
# Epoch 6/1000
# 100000/100000 [==============================] - 8s 77us/sample - loss: 9.6611 - recon_loss: 1.5629e-04 - get_kl_loss: 8.0982 - val_loss: 9.5625 - val_recon_loss: 1.5075e-04 - val_get_kl_loss: 8.0550
# Epoch 7/1000
# 100000/100000 [==============================] - 9s 88us/sample - loss: 9.5846 - recon_loss: 1.5273e-04 - get_kl_loss: 8.0573 - val_loss: 9.4597 - val_recon_loss: 1.4246e-04 - val_get_kl_loss: 8.0351
# Epoch 8/1000
# 100000/100000 [==============================] - 9s 87us/sample - loss: 9.5132 - recon_loss: 1.4841e-04 - get_kl_loss: 8.0291 - val_loss: 9.4459 - val_recon_loss: 1.4550e-04 - val_get_kl_loss: 7.9910
# Epoch 9/1000
# 100000/100000 [==============================] - 7s 70us/sample - loss: 9.4649 - recon_loss: 1.4630e-04 - get_kl_loss: 8.0019 - val_loss: 9.4011 - val_recon_loss: 1.4258e-04 - val_get_kl_loss: 7.9754
# Epoch 10/1000
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 100000/100000 [==============================] - 10s 95us/sample - loss: 5.0499 - recon_loss: 0.0037 - get_kl_loss: 4.0211 - val_loss: 5.0481 - val_recon_loss: 0.0038 - val_get_kl_loss: 3.9976
# Epoch 7/1000
# 100000/100000 [==============================] - 8s 85us/sample - loss: 5.0392 - recon_loss: 0.0037 - get_kl_loss: 4.0129 - val_loss: 5.0377 - val_recon_loss: 0.0037 - val_get_kl_loss: 4.0053
# Epoch 8/1000
# 100000/100000 [==============================] - 8s 80us/sample - loss: 5.0438 - recon_loss: 0.0037 - get_kl_loss: 4.0184 - val_loss: 5.0310 - val_recon_loss: 0.0037 - val_get_kl_loss: 4.0077
# Epoch 9/1000
# 100000/100000 [==============================] - 8s 78us/sample - loss: 5.0379 - recon_loss: 0.0037 - get_kl_loss: 4.0183 - val_loss: 5.0328 - val_recon_loss: 0.0037 - val_get_kl_loss: 4.0019
# Epoch 10/1000
#  99500/100000 [============================>.] - ETA: 0s - loss: 5.0406 - recon_loss: 0.0037 - get_kl_loss: 4.0155
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 100000/100000 [==============================] - 7s 73us/sample - loss: 5.0409 - recon_loss: 0.0037 - get_kl_loss: 4.0156 - val_loss: 5.0324 - val_recon_loss: 0.0037 - val_get_kl_loss: 4.0107
# Epoch 11/1000
# 100000/100000 [==============================] - 8s 79us/sample - loss: 5.0352 - recon_loss: 0.0037 - get_kl_loss: 4.0206 - val_loss: 5.0319 - val_recon_loss: 0.0037 - val_get_kl_loss: 4.0101
# Epoch 12/1000
#  99900/100000 [============================>.] - ETA: 0s - loss: 5.0379 - recon_loss: 0.0037 - get_kl_loss: 4.0187
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# 100000/100000 [==============================] - 8s 78us/sample - loss: 5.0381 - recon_loss: 0.0037 - get_kl_loss: 4.0188 - val_loss: 5.0407 - val_recon_loss: 0.0037 - val_get_kl_loss: 4.0089
# Latent space encoding for beta = 0.06 :

# %%
print(betas)
print(sigmas)
print(KLs)
# Out:
# [0.01 0.03 0.06 0.08 0.09 0.1  0.11 0.12 0.14 0.2  0.4  0.6  0.8  0.9
#  1.   1.1  1.2  1.4  1.6  2.   4.  ]
# [1.23999125e-04 9.39664547e-04 3.71434353e-03 6.50330074e-03
#  8.34107958e-03 1.02508962e-02 1.23275183e-02 1.42117683e-02
#  1.85486358e-02 2.93094274e-02 8.98161680e-02 1.88243061e-01
#  3.39374542e-01 4.20717537e-01 5.17438114e-01 6.28636539e-01
#  7.39068985e-01 9.99548316e-01 1.03671110e+00 1.03710449e+00
#  1.03717279e+00]
# [7.76242065e+00 5.43048573e+00 4.00893497e+00 3.42941928e+00
#  3.19269085e+00 2.97674775e+00 2.79138064e+00 2.63793397e+00
#  2.39459085e+00 1.98806262e+00 1.28814316e+00 8.84745121e-01
#  5.87832034e-01 4.69981313e-01 3.64879310e-01 2.61341304e-01
#  1.73468307e-01 1.87189057e-02 3.00556676e-05 9.84759390e-06
#  2.04966977e-06]

# %%
betas = [0.01 0.03 0.06 0.08 0.09 0.1  0.11 0.12 0.14 0.2  0.4  0.6  0.8  0.9
 1.   1.1  1.2  1.4  1.6  2.   4.  ]

# %%
delta_sigmas = np.array([sigmas[i+1] - sigmas[i] for i in range(len(sigmas)-1)])
delta_betasqrs = np.array([betas[i+1]**2 - betas[i]**2 for i in range(len(sigmas)-1)])
delta_KLs = np.array([KLs[i+1] - KLs[i] for i in range(len(sigmas)-1)])
delta_log_betas = np.array([2*np.log(betas[i+1]/betas[i]) for i in range(len(betas) - 1)])

# %%
fig,ax = plt.subplots()
ax.plot(betas[:-1],delta_sigmas/delta_betasqrs*2)
ax.plot(betas[:-1],-delta_KLs/delta_log_betas*2)
ax.plot(scales[:-1],corr_dim)
ax.semilogx()
ax.set_xlabel(r"Length Scale")
ax.set_ylabel("Dimensionality")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-c7535a00c647> in <module>()
#       1 fig,ax = plt.subplots()
# ----> 2 ax.plot(betas[:-1],delta_sigmas/delta_betasqrs*2)
#       3 ax.plot(betas[:-1],-delta_KLs/delta_log_betas*2)
#       4 ax.semilogx()
#       5 ax.set_xlabel(r"Length Scale")
#
# NameError: name 'betas' is not defined

# %% [markdown]
# The VAE is behaving like an AE. The NN has learnt some mapping between the latent space and the real space, but it is random and arbitrary.

# %% [markdown]
# ## beta = 0.01

# %%
experiment_name = '2D-VAE-beta0.01'
vae, encoder, decoder = build_and_compile_vae(beta=0.01,
                                              encoder=[256,128,64,64,32],
                                              decoder=[256,128,64,64,32],
                                             optimizer=keras.optimizers.Adam(lr=0.001))

save_period = 10
epochs = 20

train_output_dir = create_dir(osp.join(output_dir, experiment_name))
modelcheckpoint = keras.callbacks.ModelCheckpoint(train_output_dir + '/model_{epoch:02d}-{val_loss:.2e}.hdf5', period = save_period)

callbacks = [modelcheckpoint]

history = vae.fit(x=train_data, y=train_data, batch_size=100,
                epochs=epochs,verbose=1,
                validation_data = (valid_data,valid_data),
                callbacks = callbacks
              )
# Out:
# Train on 100000 samples, validate on 10000 samples
# Epoch 1/20
# 100000/100000 [==============================] - 19s 188us/step - loss: 0.1375 - val_loss: 0.1152
# Epoch 2/20
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.1067 - val_loss: 0.1050
# Epoch 3/20
# 100000/100000 [==============================] - 12s 122us/step - loss: 0.1064 - val_loss: 0.1109
# Epoch 4/20
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.1057 - val_loss: 0.1052
# Epoch 5/20
# 100000/100000 [==============================] - 12s 122us/step - loss: 0.1051 - val_loss: 0.1048
# Epoch 6/20
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.1053 - val_loss: 0.1037
# Epoch 7/20
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.1051 - val_loss: 0.1026
# Epoch 8/20
# 100000/100000 [==============================] - 12s 122us/step - loss: 0.1044 - val_loss: 0.1067
# Epoch 9/20
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.1042 - val_loss: 0.1047
# Epoch 10/20
# 100000/100000 [==============================] - 12s 124us/step - loss: 0.1041 - val_loss: 0.1049
# Epoch 11/20
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.1039 - val_loss: 0.1040
# Epoch 12/20
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.0774 - val_loss: 0.0520
# Epoch 13/20
# 100000/100000 [==============================] - 12s 122us/step - loss: 0.0557 - val_loss: 0.0611
# Epoch 14/20
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.0536 - val_loss: 0.0531
# Epoch 15/20
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.0528 - val_loss: 0.0521
# Epoch 16/20
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.0532 - val_loss: 0.0520
# Epoch 17/20
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.0531 - val_loss: 0.0534
# Epoch 18/20
# 100000/100000 [==============================] - 12s 124us/step - loss: 0.0527 - val_loss: 0.0537
# Epoch 19/20
# 100000/100000 [==============================] - 12s 124us/step - loss: 0.0529 - val_loss: 0.0526
# Epoch 20/20
# 100000/100000 [==============================] - 12s 122us/step - loss: 0.0523 - val_loss: 0.0506

# %%
print("Latent space encoding for beta = 0.01:")
plot_latent_space(encoder,valid_data)
# Out:
# Latent space encoding for beta = 0.01:

# %%
print("Latent space mapping for beta = 0.01:")
plot_latent_map(decoder,valid_data,long_axis=1)
# Out:
# Latent space mapping for beta = 0.01:

# %% [markdown]
# The VAE is well regulated, and the two latent space axes represent the two principal directions of variation in the data. There are two sharp peaks in the plot of log(variance) of the latent variables, and -9, and -5. These latent axes correspond to the long and short directions of the banana respectively. The locations of these peaks are very meaningful. There is a relation that can be deduced from inspection of the loss function. If there is a well defined length scale in the real space problem, then this will be encoded in a latent direction with variance given by L = beta / sigma, where L is the length scale, beta is the KL weight and sigma is sqrt of the variance. The peaks at around -9 and -5 map to L - 1 and 0.1 respectively. We can deduce from that that the orange latent dimension (dimension 1) corresponds to the length of the banan (which has size of order 1) while latent dimension 0 will correspond with the girth of the banana that has characteristic size of 0.1. This is established in the play above which maps the latent directions into real space.
#
# It is therefore possible to do spectroscopy of the lengthscales in the problem by looking for peaks in the distribution of variances. At least it is true in this simple toy example.
#
# A dimension becomes marginal when it is being encoded with log var ~ -1. At this point the VAE is barely able to resolve the dimension. From the plot of log variance above, I deduce that the girth of the banana will become marginal at around beta = 0.01*exp(4/2) ~ 1.

# %% [markdown]
# ## beta = 0.1

# %%
experiment_name = '2D-VAE-beta0.1'
vae, encoder, decoder = build_and_compile_vae(beta=0.1,
                                              encoder=[256,128,64,64,32],
                                              decoder=[256,128,64,64,32],
                                             optimizer=keras.optimizers.Adam(lr=0.001))

save_period = 10
epochs = 20

train_output_dir = create_dir(osp.join(output_dir, experiment_name))
modelcheckpoint = keras.callbacks.ModelCheckpoint(train_output_dir + '/model_{epoch:02d}-{val_loss:.2e}.hdf5', period = save_period)

callbacks = [modelcheckpoint]

history = vae.fit(x=train_data, y=train_data, batch_size=100,
                epochs=epochs,verbose=1,
                validation_data = (valid_data,valid_data),
                callbacks = callbacks
              )
# Out:
# Train on 100000 samples, validate on 10000 samples
# Epoch 1/20
# 100000/100000 [==============================] - 19s 189us/step - loss: 0.2783 - val_loss: 0.2472
# Epoch 2/20
# 100000/100000 [==============================] - 12s 124us/step - loss: 0.2464 - val_loss: 0.2462
# Epoch 3/20
# 100000/100000 [==============================] - 12s 122us/step - loss: 0.2453 - val_loss: 0.2416
# Epoch 4/20
# 100000/100000 [==============================] - 13s 125us/step - loss: 0.2445 - val_loss: 0.2458
# Epoch 5/20
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.2443 - val_loss: 0.2426
# Epoch 6/20
# 100000/100000 [==============================] - 12s 122us/step - loss: 0.2441 - val_loss: 0.2460
# Epoch 7/20
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.2435 - val_loss: 0.2444
# Epoch 8/20
# 100000/100000 [==============================] - 12s 124us/step - loss: 0.2436 - val_loss: 0.2431
# Epoch 9/20
# 100000/100000 [==============================] - 13s 125us/step - loss: 0.2430 - val_loss: 0.2413
# Epoch 10/20
# 100000/100000 [==============================] - 12s 124us/step - loss: 0.2426 - val_loss: 0.2415
# Epoch 11/20
# 100000/100000 [==============================] - 13s 125us/step - loss: 0.2419 - val_loss: 0.2403
# Epoch 12/20
# 100000/100000 [==============================] - 12s 124us/step - loss: 0.2421 - val_loss: 0.2408
# Epoch 13/20
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.2417 - val_loss: 0.2422
# Epoch 14/20
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.2419 - val_loss: 0.2421
# Epoch 15/20
# 100000/100000 [==============================] - 13s 126us/step - loss: 0.2417 - val_loss: 0.2430
# Epoch 16/20
# 100000/100000 [==============================] - 12s 125us/step - loss: 0.2419 - val_loss: 0.2423
# Epoch 17/20
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.2416 - val_loss: 0.2426
# Epoch 18/20
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.2415 - val_loss: 0.2417
# Epoch 19/20
# 100000/100000 [==============================] - 12s 124us/step - loss: 0.2418 - val_loss: 0.2420
# Epoch 20/20
# 100000/100000 [==============================] - 12s 124us/step - loss: 0.2410 - val_loss: 0.2405

# %%
print("Latent space encoding for beta = 0.1:")
plot_latent_space(encoder,valid_data)
# Out:
# Latent space encoding for beta = 0.1:

# %%
print("Latent space mapping for beta = 0.1:")
plot_latent_map(decoder,valid_data,long_axis=0)
# Out:
# Latent space mapping for beta = 0.1:

# %% [markdown]
# It looks like the girth can no longer be resolved. It should still be resolvable though. The ratio in the sizes of the two dimensions is a factor 10. In the variance plot, blue peaks at -5, so orange should peak at -5 + Log(100) = -0.5, but instead it has been completely pushed to 0. All points are being decoded to an average value along the girth, but still have some prediction along the length.
#
# Actually, this is a consequence of falling in a bad local minimum. There is frequently a local minumum when a latent space variable encodes nothing (satisfying the KL term), and it seems to be very difficult to escape from. I actually had to train the beta = 0.01 example many times, since it would frequently not learn the girth. I will show later that the girth is still barely resolvable at beta = 0.1 using beta-annealing.

# %% [markdown]
# ## beta = 1

# %%
experiment_name = '2D-VAE-beta1'
vae, encoder, decoder = build_and_compile_vae(beta=1.,
                                              encoder=[256,128,64,64,32],
                                              decoder=[256,128,64,64,32],
                                             optimizer=keras.optimizers.Adam(lr=0.001))

save_period = 10
epochs = 10

train_output_dir = create_dir(osp.join(output_dir, experiment_name))
modelcheckpoint = keras.callbacks.ModelCheckpoint(train_output_dir + '/model_{epoch:02d}-{val_loss:.2e}.hdf5', period = save_period)

callbacks = [modelcheckpoint]

history = vae.fit(x=train_data, y=train_data, batch_size=100,
                epochs=epochs,verbose=1,
                validation_data = (valid_data,valid_data),
                callbacks = callbacks
              )
# Out:
# Train on 100000 samples, validate on 10000 samples
# Epoch 1/10
# 100000/100000 [==============================] - 17s 166us/step - loss: 0.7658 - val_loss: 0.7630
# Epoch 2/10
# 100000/100000 [==============================] - 12s 122us/step - loss: 0.7568 - val_loss: 0.7556
# Epoch 3/10
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.7561 - val_loss: 0.7597
# Epoch 4/10
# 100000/100000 [==============================] - 12s 121us/step - loss: 0.7573 - val_loss: 0.7566
# Epoch 5/10
# 100000/100000 [==============================] - 12s 122us/step - loss: 0.7560 - val_loss: 0.7628
# Epoch 6/10
# 100000/100000 [==============================] - 12s 121us/step - loss: 0.7525 - val_loss: 0.7582
# Epoch 7/10
# 100000/100000 [==============================] - 12s 122us/step - loss: 0.7563 - val_loss: 0.7551
# Epoch 8/10
# 100000/100000 [==============================] - 12s 121us/step - loss: 0.7559 - val_loss: 0.7593
# Epoch 9/10
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.7534 - val_loss: 0.7620
# Epoch 10/10
# 100000/100000 [==============================] - 12s 122us/step - loss: 0.7534 - val_loss: 0.7560

# %%
print("Latent space encoding for beta = 1:")
plot_latent_space(encoder,valid_data)
# Out:
# Latent space encoding for beta = 1:

# %%
print("beta = 1")
plot_latent_map(decoder,valid_data,long_axis=1)
# Out:
# beta = 1

# %% [markdown]
# The short dimension is long gone and the long dimension is becoming marginal. The resolution in the long direction is O(1) and all points are being mapped to an average location along the girth.

# %% [markdown]
# ## beta = 3

# %%
experiment_name = '2D-VAE-beta3'
vae, encoder, decoder = build_and_compile_vae(beta=3.,
                                              encoder=[256,128,64,64,32],
                                              decoder=[256,128,64,64,32],
                                             optimizer=keras.optimizers.Adam(lr=0.001))

save_period = 10
epochs = 10

train_output_dir = create_dir(osp.join(output_dir, experiment_name))
modelcheckpoint = keras.callbacks.ModelCheckpoint(train_output_dir + '/model_{epoch:02d}-{val_loss:.2e}.hdf5', period = save_period)

callbacks = [modelcheckpoint]

history = vae.fit(x=train_data, y=train_data, batch_size=100,
                epochs=epochs,verbose=1,
                validation_data = (valid_data,valid_data),
                callbacks = callbacks
              )
# Out:
# Train on 100000 samples, validate on 10000 samples
# Epoch 1/10
# 100000/100000 [==============================] - 17s 168us/step - loss: 0.8272 - val_loss: 0.8264
# Epoch 2/10
# 100000/100000 [==============================] - 12s 122us/step - loss: 0.8220 - val_loss: 0.8270
# Epoch 3/10
# 100000/100000 [==============================] - 12s 122us/step - loss: 0.8218 - val_loss: 0.8270
# Epoch 4/10
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.8218 - val_loss: 0.8269
# Epoch 5/10
# 100000/100000 [==============================] - 12s 122us/step - loss: 0.8219 - val_loss: 0.8272
# Epoch 6/10
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.8217 - val_loss: 0.8264
# Epoch 7/10
# 100000/100000 [==============================] - 12s 121us/step - loss: 0.8216 - val_loss: 0.8266
# Epoch 8/10
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.8215 - val_loss: 0.8264
# Epoch 9/10
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.8216 - val_loss: 0.8265
# Epoch 10/10
# 100000/100000 [==============================] - 12s 123us/step - loss: 0.8215 - val_loss: 0.8263

# %%
print("Latent space encoding for beta = 1:")
plot_latent_space(encoder,valid_data)
# Out:
# Latent space encoding for beta = 1:

# %%
print("beta = 1")
plot_latent_map(decoder,valid_data,long_axis=1)
# Out:
# beta = 1

# %% [markdown]
# The long dimension is now also unresolvable. The encoder chooses to encode no information about the input into the latent space. The decoder has learnt to ignore the latent space, and to map everything to an average point in the real space.

# %% [markdown]
# ### Commentary
#
# Beta sets the resolution for the VAE, and the VAE may not resolve information below the scale set by beta. So for beta above 0.1, the VAE cannot resolve the dimension with typical size 0.1. For beta above 1, it cannot resolve the dimension with typical size 1.
#
# For very small beta (compared to the length scales of interest), the VAE behaves like an AE. It encodes all the information it can into the latent space, but in a way that is not regulated and is difficult to interpret. As beta becomes marginal for some axes of variation, some latent space dimensions begin to align with those axes. If the length scales are sharp (as they are in this toy dataset), the distribution of encoded variances forms a peak that maps directly to the corresponding length scale, allowing you to perform spectroscopy.
#
# The latent space should be as large as possible. It is beta that forces a dimensional reduction. For 0.1 < beta < 1, the latent space was in principle 2D, but it was clear that only one of them was encoding information. By using beta instead of the number of latent dimensions to control the dimensional reduction, we are encouraging the VAE to organise information hierarchically according to importance (where importance is defined only with respect to that metric that is used for defining the reconstruction loss).
#
# When beta is marginal, it becomes very difficult to train the VAE as it falls into local minima where it is discarding information that would actually be encoded in the global minimum. This is fixed with beta annealing below

# %% [markdown]
# # Beta annealing
#
# The idea is to start training at very small beta, so the VAE learns to encode a poorly regulated but high-information encoding of the information into the latent space. As you then increase beta, the latent directions become well regulated and begin to align with axes of variance present in the training dataset. Dimensions will only be forgetten when beta truly crosses over the threshold of marginality.

# %%
def build_and_compile_annealing_vae(encoder = [512,256,128,64,32],
                                    decoder = [512,256,128,64,32],
                                    verbose=0,dropout=0,
                                    optimizer=keras.optimizers.Adam()):
    
    def sampling(args):
        """Reparameterization trick by sampling fr an isotropic unit Gaussian.

        # Arguments
            args (tensor): mean and log of variance of Q(z|X)

        # Returns
            z (tensor): sampled latent vector
        """

        z_mean, z_log_var = args
        batch = K.shape(z_mean)[0]
        dim = K.int_shape(z_mean)[1]
        # by default, random_normal has mean=0 and std=1.0
        epsilon = K.random_normal(shape=(batch, dim))
        return z_mean + K.exp(0.5 * z_log_var) * epsilon

    latent_dim = 2
    #Encoder
    inputs = tf.keras.Input(shape=(2,))
    beta_input = tf.keras.Input(shape=(1,))
#     layer = inputs
    layer = tf.keras.layers.Concatenate()([inputs,beta_input])
    layer = Lambda(lambda x: x[:,:2])(layer)
    for layer_size in encoder:
        layer = Dense(layer_size,bias_initializer='glorot_uniform')(layer)
        layer = keras.layers.ReLU()(layer)
        if dropout > 0:
            layer = keras.layers.Dropout(dropout)(layer)
        

    #Bottleneck
    z_mean = Dense(latent_dim, name='z_mean')(layer)
    z_log_var = Dense(latent_dim, name='z_log_var')(layer)
    z = Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean, z_log_var])

    encoder = Model([inputs,beta_input], [z_mean, z_log_var, z], name='encoder')
    if verbose:
        encoder.summary()
    #plot_model(encoder, to_file='CNN-VAE_encoder.png', show_shapes=True)

    #Decoder
    latent_inputs = Input(shape=(latent_dim,), name='z_sampling')
    layer = latent_inputs
    
    for layer_size in decoder:
        layer = Dense(layer_size,bias_initializer='glorot_uniform')(layer)
        layer = keras.layers.ReLU()(layer)
        if dropout > 0:
            layer = keras.layers.Dropout(dropout)(layer)
            
    decoded = Dense(2)(layer)

    decoder = Model(latent_inputs, decoded, name='decoder')
    if verbose:
        decoder.summary()
    #plot_model(decoder, to_file='CNN-VAE_decoder.png', show_shapes=True)


    outputs = decoder(encoder([inputs,beta_input])[2])
    vae = Model([inputs,beta_input], outputs, name='CNN-VAE')

    def beta_vae_loss(beta):
        def vae_loss(x, x_decoded_mean):
            xent_loss = K.sqrt(K.sum(K.square(x - x_decoded_mean),axis=-1))
            kl_loss = - 0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
            return K.mean(xent_loss + beta * kl_loss)
        return vae_loss
    
    def recon_loss(x, x_decoded_mean):
        recon_loss = K.sqrt(K.sum(K.square(x - x_decoded_mean),axis=-1))
        return K.mean(recon_loss)
    
    def kl_loss(beta):
        def get_kl_loss(x, x_decoded_mean):
            kl_loss = - 0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
            return K.mean( beta * kl_loss)
        return get_kl_loss
    
    vae.compile(loss=beta_vae_loss(beta_input),
                optimizer=optimizer,
                metrics = [recon_loss,kl_loss(beta_input)]
               )
    
    vae.summary()
    
    return vae, encoder, decoder

save_period = 10
modelcheckpoint = keras.callbacks.ModelCheckpoint(train_output_dir + '/model_{epoch:02d}-{val_loss:.2e}.hdf5', period = save_period)
reduceLR = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4, verbose=1, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)
earlystop = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=6, verbose=0, mode='auto', baseline=None, restore_best_weights=False)

callbacks = [modelcheckpoint,reduceLR,earlystop]

class encoder_class():
    def __init__(self,encoder):
        self.encoder = encoder
        
    def predict(self, data):
        return self.encoder.predict([data,np.ones(len(data))])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.

# %%
experiment_name = '2D-VAE-beta-anneal'
vae, encoder, decoder = build_and_compile_annealing_vae(encoder=[256,128,64,64,32],
                                                        decoder=[256,128,64,64,32],
                                                        optimizer=keras.optimizers.Adam(lr=0.001))
# Out:
# Model: "CNN-VAE"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_68 (InputLayer)           [(None, 2)]          0
# __________________________________________________________________________________________________
# input_69 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# encoder (Model)                 [(None, 2), (None, 2 48292       input_68[0][0]
#                                                                  input_69[0][0]
# __________________________________________________________________________________________________
# decoder (Model)                 (None, 2)            48226       encoder[1][2]
# ==================================================================================================
# Total params: 96,518
# Trainable params: 96,518
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
beta = 0.0001
epochs = 50
history = vae.fit(x=[train_data,np.ones(len(train_data))*beta], y=train_data, batch_size=100,
                epochs=epochs,verbose=1,
                validation_data = ([valid_data,np.ones(len(valid_data))*beta],valid_data),
                callbacks = callbacks
              )

# tf.saved_model.save(vae, train_output_dir + '/mymodel.hdf5')
# Out:
# Train on 100000 samples, validate on 10000 samples
# Epoch 1/50
# 100000/100000 [==============================] - 19s 189us/sample - loss: 0.1094 - get_xent_loss: 0.1083 - get_kl_loss: 0.0011 - val_loss: 0.0866 - val_get_xent_loss: 0.0855 - val_get_kl_loss: 0.0011
# Epoch 2/50
# 100000/100000 [==============================] - 15s 147us/sample - loss: 0.0819 - get_xent_loss: 0.0809 - get_kl_loss: 0.0010 - val_loss: 0.0811 - val_get_xent_loss: 0.0801 - val_get_kl_loss: 9.9846e-04
# Epoch 3/50
# 100000/100000 [==============================] - 16s 157us/sample - loss: 0.0516 - get_xent_loss: 0.0501 - get_kl_loss: 0.0014 - val_loss: 0.0213 - val_get_xent_loss: 0.0196 - val_get_kl_loss: 0.0017
# Epoch 4/50
# 100000/100000 [==============================] - 15s 147us/sample - loss: 0.0200 - get_xent_loss: 0.0182 - get_kl_loss: 0.0017 - val_loss: 0.0113 - val_get_xent_loss: 0.0096 - val_get_kl_loss: 0.0017
# Epoch 5/50
# 100000/100000 [==============================] - 14s 142us/sample - loss: 0.0166 - get_xent_loss: 0.0149 - get_kl_loss: 0.0017 - val_loss: 0.0125 - val_get_xent_loss: 0.0108 - val_get_kl_loss: 0.0017
# Epoch 6/50
# 100000/100000 [==============================] - 13s 132us/sample - loss: 0.0145 - get_xent_loss: 0.0128 - get_kl_loss: 0.0017 - val_loss: 0.0117 - val_get_xent_loss: 0.0100 - val_get_kl_loss: 0.0017
# Epoch 7/50
# 100000/100000 [==============================] - 14s 141us/sample - loss: 0.0139 - get_xent_loss: 0.0122 - get_kl_loss: 0.0017 - val_loss: 0.0071 - val_get_xent_loss: 0.0054 - val_get_kl_loss: 0.0016
# Epoch 8/50
# 100000/100000 [==============================] - 15s 146us/sample - loss: 0.0140 - get_xent_loss: 0.0124 - get_kl_loss: 0.0016 - val_loss: 0.0135 - val_get_xent_loss: 0.0120 - val_get_kl_loss: 0.0016
# Epoch 9/50
# 100000/100000 [==============================] - 14s 142us/sample - loss: 0.0131 - get_xent_loss: 0.0115 - get_kl_loss: 0.0016 - val_loss: 0.0096 - val_get_xent_loss: 0.0080 - val_get_kl_loss: 0.0015
# Epoch 10/50
# 100000/100000 [==============================] - 19s 189us/sample - loss: 0.0124 - get_xent_loss: 0.0109 - get_kl_loss: 0.0015 - val_loss: 0.0160 - val_get_xent_loss: 0.0146 - val_get_kl_loss: 0.0015
# Epoch 11/50
#  99600/100000 [============================>.] - ETA: 0s - loss: 0.0125 - get_xent_loss: 0.0110 - get_kl_loss: 0.0015
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 100000/100000 [==============================] - 17s 169us/sample - loss: 0.0125 - get_xent_loss: 0.0110 - get_kl_loss: 0.0015 - val_loss: 0.0096 - val_get_xent_loss: 0.0081 - val_get_kl_loss: 0.0015
# Epoch 12/50
# 100000/100000 [==============================] - 14s 140us/sample - loss: 0.0035 - get_xent_loss: 0.0019 - get_kl_loss: 0.0016 - val_loss: 0.0033 - val_get_xent_loss: 0.0016 - val_get_kl_loss: 0.0016
# Epoch 13/50
# 100000/100000 [==============================] - 14s 142us/sample - loss: 0.0032 - get_xent_loss: 0.0016 - get_kl_loss: 0.0017 - val_loss: 0.0029 - val_get_xent_loss: 0.0012 - val_get_kl_loss: 0.0016
# Epoch 14/50
# 100000/100000 [==============================] - 14s 141us/sample - loss: 0.0032 - get_xent_loss: 0.0015 - get_kl_loss: 0.0017 - val_loss: 0.0029 - val_get_xent_loss: 0.0012 - val_get_kl_loss: 0.0017
# Epoch 15/50
# 100000/100000 [==============================] - 14s 136us/sample - loss: 0.0031 - get_xent_loss: 0.0015 - get_kl_loss: 0.0017 - val_loss: 0.0033 - val_get_xent_loss: 0.0016 - val_get_kl_loss: 0.0016
# Epoch 16/50
# 100000/100000 [==============================] - 14s 142us/sample - loss: 0.0031 - get_xent_loss: 0.0015 - get_kl_loss: 0.0017 - val_loss: 0.0030 - val_get_xent_loss: 0.0013 - val_get_kl_loss: 0.0016
# Epoch 17/50
#  99600/100000 [============================>.] - ETA: 0s - loss: 0.0031 - get_xent_loss: 0.0014 - get_kl_loss: 0.0017
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 100000/100000 [==============================] - 14s 135us/sample - loss: 0.0031 - get_xent_loss: 0.0014 - get_kl_loss: 0.0017 - val_loss: 0.0032 - val_get_xent_loss: 0.0015 - val_get_kl_loss: 0.0016
# Epoch 18/50
# 100000/100000 [==============================] - 14s 139us/sample - loss: 0.0026 - get_xent_loss: 8.9935e-04 - get_kl_loss: 0.0017 - val_loss: 0.0025 - val_get_xent_loss: 8.6028e-04 - val_get_kl_loss: 0.0017
# Epoch 19/50
# 100000/100000 [==============================] - 14s 137us/sample - loss: 0.0025 - get_xent_loss: 8.6688e-04 - get_kl_loss: 0.0017 - val_loss: 0.0025 - val_get_xent_loss: 8.7900e-04 - val_get_kl_loss: 0.0017
# Epoch 20/50
# 100000/100000 [==============================] - 14s 137us/sample - loss: 0.0025 - get_xent_loss: 8.5277e-04 - get_kl_loss: 0.0017 - val_loss: 0.0025 - val_get_xent_loss: 8.3089e-04 - val_get_kl_loss: 0.0017
# Epoch 21/50
# 100000/100000 [==============================] - 13s 133us/sample - loss: 0.0025 - get_xent_loss: 8.4537e-04 - get_kl_loss: 0.0017 - val_loss: 0.0025 - val_get_xent_loss: 8.1084e-04 - val_get_kl_loss: 0.0017
# Epoch 22/50
# 100000/100000 [==============================] - 13s 135us/sample - loss: 0.0025 - get_xent_loss: 8.3247e-04 - get_kl_loss: 0.0017 - val_loss: 0.0025 - val_get_xent_loss: 8.1082e-04 - val_get_kl_loss: 0.0017
# Epoch 23/50
# 100000/100000 [==============================] - 14s 137us/sample - loss: 0.0025 - get_xent_loss: 8.3111e-04 - get_kl_loss: 0.0017 - val_loss: 0.0025 - val_get_xent_loss: 8.2089e-04 - val_get_kl_loss: 0.0017
# Epoch 24/50
# 100000/100000 [==============================] - 13s 133us/sample - loss: 0.0025 - get_xent_loss: 8.1778e-04 - get_kl_loss: 0.0017 - val_loss: 0.0025 - val_get_xent_loss: 8.1366e-04 - val_get_kl_loss: 0.0017
# Epoch 25/50
# 100000/100000 [==============================] - 13s 132us/sample - loss: 0.0025 - get_xent_loss: 8.0811e-04 - get_kl_loss: 0.0017 - val_loss: 0.0025 - val_get_xent_loss: 7.7453e-04 - val_get_kl_loss: 0.0017
# Epoch 26/50
# 100000/100000 [==============================] - 13s 131us/sample - loss: 0.0025 - get_xent_loss: 7.9976e-04 - get_kl_loss: 0.0017 - val_loss: 0.0025 - val_get_xent_loss: 7.9026e-04 - val_get_kl_loss: 0.0017
# Epoch 27/50
# 100000/100000 [==============================] - 14s 143us/sample - loss: 0.0025 - get_xent_loss: 7.9814e-04 - get_kl_loss: 0.0017 - val_loss: 0.0025 - val_get_xent_loss: 7.7285e-04 - val_get_kl_loss: 0.0017
# Epoch 28/50
#  18300/100000 [====>.........................] - ETA: 10s - loss: 0.0025 - get_xent_loss: 8.1821e-04 - get_kl_loss: 0.0017
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-120-017d55e0e805> in <module>()
#       4                 epochs=epochs,verbose=1,
#       5                 validation_data = ([valid_data,np.ones(len(valid_data))*beta],valid_data),
# ----> 6                 callbacks = callbacks
#       7               )
#       8
#
# /home/jack/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     778           validation_steps=validation_steps,
#     779           validation_freq=validation_freq,
# --> 780           steps_name='steps_per_epoch')
#     781
#     782   def evaluate(self,
#
# /home/jack/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     361
#     362         # Get outputs.
# --> 363         batch_outs = f(ins_batch)
#     364         if not isinstance(batch_outs, list):
#     365           batch_outs = [batch_outs]
#
# /home/jack/.local/lib/python3.6/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3251     inputs = nest.flatten(inputs)
#    3252
# -> 3253     session = get_session(inputs)
#    3254     feed_arrays = []
#    3255     array_vals = []
#
# /home/jack/.local/lib/python3.6/site-packages/tensorflow/python/keras/backend.py in get_session(op_input_list)
#     460   if not _MANUAL_VAR_INIT:
#     461     with session.graph.as_default():
# --> 462       _initialize_variables(session)
#     463   return session
#     464
#
# /home/jack/.local/lib/python3.6/site-packages/tensorflow/python/keras/backend.py in _initialize_variables(session)
#     871   candidate_vars = []
#     872   for v in variables:
# --> 873     if not getattr(v, '_keras_initialized', False):
#     874       candidate_vars.append(v)
#     875   if candidate_vars:
#
# KeyboardInterrupt:

# %%
print("Latent space encoding for beta =",beta,":")


myencoder = encoder_class(encoder)
    
plot_latent_space(myencoder,valid_data)
# Out:
# Latent space encoding for beta = 0.0001 :

# %%
print("Latent space mapping for beta = ",beta,":")
plot_latent_map(myencoder,decoder,valid_data,long_axis=0)
# Out:
# Latent space mapping for beta =  0.0001 :

# %%
beta = 0.001
K.set_value(vae.optimizer.lr,1e-3)
epochs = 50
history = vae.fit(x=[train_data,np.ones(len(train_data))*beta], y=train_data, batch_size=100,
                epochs=epochs,verbose=1,initial_epoch=history.epoch[-1],
                validation_data = ([valid_data,np.ones(len(valid_data))*beta],valid_data),
                callbacks = callbacks
              )

# tf.saved_model.save(vae, train_output_dir + '/mymodel.hdf5')
# Out:
# Train on 100000 samples, validate on 10000 samples
# Epoch 7/50
# 100000/100000 [==============================] - 16s 158us/sample - loss: 0.0259 - get_xent_loss: 0.0153 - get_kl_loss: 0.0106 - val_loss: 0.0194 - val_get_xent_loss: 0.0095 - val_get_kl_loss: 0.0100
# Epoch 8/50
# 100000/100000 [==============================] - 15s 151us/sample - loss: 0.0216 - get_xent_loss: 0.0115 - get_kl_loss: 0.0101 - val_loss: 0.0219 - val_get_xent_loss: 0.0122 - val_get_kl_loss: 0.0098
# Epoch 9/50
# 100000/100000 [==============================] - 16s 159us/sample - loss: 0.0203 - get_xent_loss: 0.0103 - get_kl_loss: 0.0100 - val_loss: 0.0201 - val_get_xent_loss: 0.0103 - val_get_kl_loss: 0.0099
# Epoch 10/50
# 100000/100000 [==============================] - 15s 153us/sample - loss: 0.0205 - get_xent_loss: 0.0107 - get_kl_loss: 0.0098 - val_loss: 0.0170 - val_get_xent_loss: 0.0071 - val_get_kl_loss: 0.0099
# Epoch 11/50
# 100000/100000 [==============================] - 14s 136us/sample - loss: 0.0201 - get_xent_loss: 0.0103 - get_kl_loss: 0.0098 - val_loss: 0.0247 - val_get_xent_loss: 0.0151 - val_get_kl_loss: 0.0096
# Epoch 12/50
# 100000/100000 [==============================] - 9s 94us/sample - loss: 0.0200 - get_xent_loss: 0.0102 - get_kl_loss: 0.0097 - val_loss: 0.0177 - val_get_xent_loss: 0.0080 - val_get_kl_loss: 0.0097
# Epoch 13/50
# 100000/100000 [==============================] - 12s 118us/sample - loss: 0.0197 - get_xent_loss: 0.0100 - get_kl_loss: 0.0097 - val_loss: 0.0209 - val_get_xent_loss: 0.0110 - val_get_kl_loss: 0.0099
# Epoch 14/50
#  99600/100000 [============================>.] - ETA: 0s - loss: 0.0194 - get_xent_loss: 0.0097 - get_kl_loss: 0.0097
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 100000/100000 [==============================] - 13s 125us/sample - loss: 0.0194 - get_xent_loss: 0.0097 - get_kl_loss: 0.0097 - val_loss: 0.0207 - val_get_xent_loss: 0.0108 - val_get_kl_loss: 0.0098
# Epoch 15/50
# 100000/100000 [==============================] - 12s 120us/sample - loss: 0.0139 - get_xent_loss: 0.0033 - get_kl_loss: 0.0105 - val_loss: 0.0138 - val_get_xent_loss: 0.0031 - val_get_kl_loss: 0.0107
# Epoch 16/50
# 100000/100000 [==============================] - 12s 124us/sample - loss: 0.0138 - get_xent_loss: 0.0030 - get_kl_loss: 0.0107 - val_loss: 0.0137 - val_get_xent_loss: 0.0030 - val_get_kl_loss: 0.0107
# Epoch 17/50
# 100000/100000 [==============================] - 9s 90us/sample - loss: 0.0137 - get_xent_loss: 0.0030 - get_kl_loss: 0.0107 - val_loss: 0.0137 - val_get_xent_loss: 0.0030 - val_get_kl_loss: 0.0107
# Epoch 18/50
# 100000/100000 [==============================] - 10s 101us/sample - loss: 0.0138 - get_xent_loss: 0.0030 - get_kl_loss: 0.0107 - val_loss: 0.0136 - val_get_xent_loss: 0.0029 - val_get_kl_loss: 0.0107
# Epoch 19/50
# 100000/100000 [==============================] - 10s 98us/sample - loss: 0.0137 - get_xent_loss: 0.0030 - get_kl_loss: 0.0107 - val_loss: 0.0134 - val_get_xent_loss: 0.0027 - val_get_kl_loss: 0.0107
# Epoch 20/50
# 100000/100000 [==============================] - 9s 89us/sample - loss: 0.0137 - get_xent_loss: 0.0030 - get_kl_loss: 0.0107 - val_loss: 0.0135 - val_get_xent_loss: 0.0028 - val_get_kl_loss: 0.0107
# Epoch 21/50
# 100000/100000 [==============================] - 8s 80us/sample - loss: 0.0136 - get_xent_loss: 0.0029 - get_kl_loss: 0.0107 - val_loss: 0.0136 - val_get_xent_loss: 0.0029 - val_get_kl_loss: 0.0107
# Epoch 22/50
# 100000/100000 [==============================] - 8s 81us/sample - loss: 0.0137 - get_xent_loss: 0.0029 - get_kl_loss: 0.0107 - val_loss: 0.0134 - val_get_xent_loss: 0.0027 - val_get_kl_loss: 0.0107
# Epoch 23/50
# 100000/100000 [==============================] - 9s 87us/sample - loss: 0.0137 - get_xent_loss: 0.0030 - get_kl_loss: 0.0107 - val_loss: 0.0136 - val_get_xent_loss: 0.0029 - val_get_kl_loss: 0.0107
# Epoch 24/50
# 100000/100000 [==============================] - 9s 85us/sample - loss: 0.0136 - get_xent_loss: 0.0029 - get_kl_loss: 0.0107 - val_loss: 0.0138 - val_get_xent_loss: 0.0032 - val_get_kl_loss: 0.0107
# Epoch 25/50
# 100000/100000 [==============================] - 8s 79us/sample - loss: 0.0136 - get_xent_loss: 0.0029 - get_kl_loss: 0.0107 - val_loss: 0.0137 - val_get_xent_loss: 0.0030 - val_get_kl_loss: 0.0107
# Epoch 26/50
#  99700/100000 [============================>.] - ETA: 0s - loss: 0.0137 - get_xent_loss: 0.0030 - get_kl_loss: 0.0107
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 100000/100000 [==============================] - 8s 77us/sample - loss: 0.0137 - get_xent_loss: 0.0030 - get_kl_loss: 0.0107 - val_loss: 0.0136 - val_get_xent_loss: 0.0030 - val_get_kl_loss: 0.0106
# Epoch 27/50
# 100000/100000 [==============================] - 8s 77us/sample - loss: 0.0132 - get_xent_loss: 0.0025 - get_kl_loss: 0.0107 - val_loss: 0.0132 - val_get_xent_loss: 0.0024 - val_get_kl_loss: 0.0108
# Epoch 28/50
# 100000/100000 [==============================] - 16s 155us/sample - loss: 0.0132 - get_xent_loss: 0.0024 - get_kl_loss: 0.0108 - val_loss: 0.0132 - val_get_xent_loss: 0.0024 - val_get_kl_loss: 0.0108
# Epoch 29/50
# 100000/100000 [==============================] - 19s 188us/sample - loss: 0.0132 - get_xent_loss: 0.0024 - get_kl_loss: 0.0109 - val_loss: 0.0132 - val_get_xent_loss: 0.0024 - val_get_kl_loss: 0.0108
# Epoch 30/50
# 100000/100000 [==============================] - 16s 163us/sample - loss: 0.0132 - get_xent_loss: 0.0023 - get_kl_loss: 0.0109 - val_loss: 0.0133 - val_get_xent_loss: 0.0024 - val_get_kl_loss: 0.0109
# Epoch 31/50
#  99400/100000 [============================>.] - ETA: 0s - loss: 0.0132 - get_xent_loss: 0.0023 - get_kl_loss: 0.0109
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 100000/100000 [==============================] - 13s 129us/sample - loss: 0.0132 - get_xent_loss: 0.0023 - get_kl_loss: 0.0109 - val_loss: 0.0132 - val_get_xent_loss: 0.0023 - val_get_kl_loss: 0.0109
# Epoch 32/50
# 100000/100000 [==============================] - 9s 89us/sample - loss: 0.0132 - get_xent_loss: 0.0023 - get_kl_loss: 0.0109 - val_loss: 0.0132 - val_get_xent_loss: 0.0023 - val_get_kl_loss: 0.0109
# Epoch 33/50
# 100000/100000 [==============================] - 8s 85us/sample - loss: 0.0132 - get_xent_loss: 0.0023 - get_kl_loss: 0.0109 - val_loss: 0.0132 - val_get_xent_loss: 0.0023 - val_get_kl_loss: 0.0109
# Epoch 34/50
# 100000/100000 [==============================] - 8s 84us/sample - loss: 0.0132 - get_xent_loss: 0.0023 - get_kl_loss: 0.0109 - val_loss: 0.0131 - val_get_xent_loss: 0.0023 - val_get_kl_loss: 0.0109
# Epoch 35/50
# 100000/100000 [==============================] - 8s 80us/sample - loss: 0.0132 - get_xent_loss: 0.0023 - get_kl_loss: 0.0109 - val_loss: 0.0132 - val_get_xent_loss: 0.0023 - val_get_kl_loss: 0.0109
# Epoch 36/50
# 100000/100000 [==============================] - 8s 77us/sample - loss: 0.0131 - get_xent_loss: 0.0023 - get_kl_loss: 0.0109 - val_loss: 0.0131 - val_get_xent_loss: 0.0023 - val_get_kl_loss: 0.0109
# Epoch 37/50
# 100000/100000 [==============================] - 8s 77us/sample - loss: 0.0132 - get_xent_loss: 0.0023 - get_kl_loss: 0.0109 - val_loss: 0.0132 - val_get_xent_loss: 0.0023 - val_get_kl_loss: 0.0109
# Epoch 38/50
#  99300/100000 [============================>.] - ETA: 0s - loss: 0.0132 - get_xent_loss: 0.0023 - get_kl_loss: 0.0109
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 100000/100000 [==============================] - 8s 77us/sample - loss: 0.0132 - get_xent_loss: 0.0023 - get_kl_loss: 0.0109 - val_loss: 0.0132 - val_get_xent_loss: 0.0023 - val_get_kl_loss: 0.0109
# Epoch 39/50
# 100000/100000 [==============================] - 9s 93us/sample - loss: 0.0131 - get_xent_loss: 0.0022 - get_kl_loss: 0.0109 - val_loss: 0.0132 - val_get_xent_loss: 0.0023 - val_get_kl_loss: 0.0109
# Epoch 40/50
# 100000/100000 [==============================] - 8s 81us/sample - loss: 0.0131 - get_xent_loss: 0.0022 - get_kl_loss: 0.0109 - val_loss: 0.0131 - val_get_xent_loss: 0.0023 - val_get_kl_loss: 0.0109

# %%
print("Latent space encoding for beta =",beta,":")
myencoder = encoder_class(encoder)
    
plot_latent_space(myencoder,valid_data)
# Out:
# Latent space encoding for beta = 0.01 :

# %%
print("Latent space mapping for beta = ",beta,":")
plot_latent_map(myencoder,decoder,valid_data,scales = np.array([[-2,2],[-4,4]]),latent_plotrange = [-5,5])
# Out:
# Latent space mapping for beta =  0.01 :

# %% [markdown]
# The latent space is starting to become regulated, as can be seen manifested in all five plots above. Maybe it would have been even better if I trained for more than one epoch.
#
# ### beta = 0.01
#
# Increase by a factor of only 3 this time because it is starting to get interesting

# %%
beta = 0.01
K.set_value(vae.optimizer.lr,1e-3)
epochs = 50
history = vae.fit(x=[train_data,np.ones(len(train_data))*beta], y=train_data, batch_size=100,
                epochs=epochs,verbose=1,initial_epoch=history.epoch[-1],
                validation_data = ([valid_data,np.ones(len(valid_data))*beta],valid_data),
                callbacks = callbacks
              )

# tf.saved_model.save(vae, train_output_dir + '/mymodel.hdf5')
# Out:
# Train on 100000 samples, validate on 10000 samples
# Epoch 40/50
# 100000/100000 [==============================] - 8s 83us/sample - loss: 0.0837 - get_xent_loss: 0.0263 - get_kl_loss: 0.0574 - val_loss: 0.0823 - val_get_xent_loss: 0.0251 - val_get_kl_loss: 0.0572
# Epoch 41/50
# 100000/100000 [==============================] - 8s 79us/sample - loss: 0.0840 - get_xent_loss: 0.0269 - get_kl_loss: 0.0571 - val_loss: 0.0814 - val_get_xent_loss: 0.0232 - val_get_kl_loss: 0.0582
# Epoch 42/50
# 100000/100000 [==============================] - 8s 80us/sample - loss: 0.0836 - get_xent_loss: 0.0262 - get_kl_loss: 0.0573 - val_loss: 0.0817 - val_get_xent_loss: 0.0237 - val_get_kl_loss: 0.0580
# Epoch 43/50
# 100000/100000 [==============================] - 8s 81us/sample - loss: 0.0836 - get_xent_loss: 0.0263 - get_kl_loss: 0.0573 - val_loss: 0.0817 - val_get_xent_loss: 0.0234 - val_get_kl_loss: 0.0583
# Epoch 44/50
# 100000/100000 [==============================] - 8s 77us/sample - loss: 0.0836 - get_xent_loss: 0.0264 - get_kl_loss: 0.0573 - val_loss: 0.0868 - val_get_xent_loss: 0.0293 - val_get_kl_loss: 0.0575
# Epoch 45/50
#  99700/100000 [============================>.] - ETA: 0s - loss: 0.0835 - get_xent_loss: 0.0260 - get_kl_loss: 0.0574
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 100000/100000 [==============================] - 8s 76us/sample - loss: 0.0835 - get_xent_loss: 0.0260 - get_kl_loss: 0.0574 - val_loss: 0.0818 - val_get_xent_loss: 0.0245 - val_get_kl_loss: 0.0573
# Epoch 46/50
# 100000/100000 [==============================] - 8s 77us/sample - loss: 0.0804 - get_xent_loss: 0.0211 - get_kl_loss: 0.0592 - val_loss: 0.0804 - val_get_xent_loss: 0.0211 - val_get_kl_loss: 0.0592
# Epoch 47/50
# 100000/100000 [==============================] - 8s 77us/sample - loss: 0.0803 - get_xent_loss: 0.0209 - get_kl_loss: 0.0594 - val_loss: 0.0801 - val_get_xent_loss: 0.0208 - val_get_kl_loss: 0.0593
# Epoch 48/50
# 100000/100000 [==============================] - 10s 101us/sample - loss: 0.0804 - get_xent_loss: 0.0209 - get_kl_loss: 0.0594 - val_loss: 0.0802 - val_get_xent_loss: 0.0207 - val_get_kl_loss: 0.0595
# Epoch 49/50
# 100000/100000 [==============================] - 12s 119us/sample - loss: 0.0803 - get_xent_loss: 0.0210 - get_kl_loss: 0.0593 - val_loss: 0.0803 - val_get_xent_loss: 0.0209 - val_get_kl_loss: 0.0594
# Epoch 50/50
# 100000/100000 [==============================] - 12s 121us/sample - loss: 0.0803 - get_xent_loss: 0.0210 - get_kl_loss: 0.0593 - val_loss: 0.0802 - val_get_xent_loss: 0.0208 - val_get_kl_loss: 0.0594

# %%
print("Latent space encoding for beta =",beta,":")
myencoder = encoder_class(encoder)
    
plot_latent_space(myencoder,valid_data)
# Out:
# Latent space encoding for beta = 0.01 :

# %%
print("Latent space mapping for beta = ",beta,":")
plot_latent_map(myencoder,decoder,valid_data,scales = np.array([[-3,3],[-3,3]]),latent_plotrange = [-5,5])
# Out:
# Latent space mapping for beta =  0.01 :

# %%
beta = 0.03
K.set_value(vae.optimizer.lr,1e-3)
epochs = history.epoch[-1] + 50
history = vae.fit(x=[train_data,np.ones(len(train_data))*beta], y=train_data, batch_size=100,
                epochs=epochs,verbose=1,initial_epoch=history.epoch[-1],
                validation_data = ([valid_data,np.ones(len(valid_data))*beta],valid_data),
                callbacks = callbacks
              )

# tf.saved_model.save(vae, train_output_dir + '/mymodel.hdf5')
# Out:
# Train on 100000 samples, validate on 10000 samples
# Epoch 50/99
# 100000/100000 [==============================] - 8s 79us/sample - loss: 0.1770 - get_xent_loss: 0.0684 - get_kl_loss: 0.1087 - val_loss: 0.1745 - val_get_xent_loss: 0.0649 - val_get_kl_loss: 0.1095
# Epoch 51/99
# 100000/100000 [==============================] - 8s 76us/sample - loss: 0.1764 - get_xent_loss: 0.0671 - get_kl_loss: 0.1093 - val_loss: 0.1775 - val_get_xent_loss: 0.0693 - val_get_kl_loss: 0.1082
# Epoch 52/99
# 100000/100000 [==============================] - 8s 76us/sample - loss: 0.1765 - get_xent_loss: 0.0671 - get_kl_loss: 0.1095 - val_loss: 0.1745 - val_get_xent_loss: 0.0658 - val_get_kl_loss: 0.1087
# Epoch 53/99
# 100000/100000 [==============================] - 8s 76us/sample - loss: 0.1766 - get_xent_loss: 0.0674 - get_kl_loss: 0.1091 - val_loss: 0.1764 - val_get_xent_loss: 0.0673 - val_get_kl_loss: 0.1091
# Epoch 54/99
#  99900/100000 [============================>.] - ETA: 0s - loss: 0.1766 - get_xent_loss: 0.0675 - get_kl_loss: 0.1091
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 100000/100000 [==============================] - 8s 77us/sample - loss: 0.1766 - get_xent_loss: 0.0675 - get_kl_loss: 0.1091 - val_loss: 0.1768 - val_get_xent_loss: 0.0680 - val_get_kl_loss: 0.1088
# Epoch 55/99
# 100000/100000 [==============================] - 11s 114us/sample - loss: 0.1735 - get_xent_loss: 0.0621 - get_kl_loss: 0.1113 - val_loss: 0.1733 - val_get_xent_loss: 0.0617 - val_get_kl_loss: 0.1117
# Epoch 56/99
# 100000/100000 [==============================] - 10s 96us/sample - loss: 0.1734 - get_xent_loss: 0.0617 - get_kl_loss: 0.1116 - val_loss: 0.1734 - val_get_xent_loss: 0.0617 - val_get_kl_loss: 0.1117
# Epoch 57/99
# 100000/100000 [==============================] - 10s 97us/sample - loss: 0.1735 - get_xent_loss: 0.0618 - get_kl_loss: 0.1117 - val_loss: 0.1732 - val_get_xent_loss: 0.0616 - val_get_kl_loss: 0.1117
# Epoch 58/99
# 100000/100000 [==============================] - 10s 96us/sample - loss: 0.1734 - get_xent_loss: 0.0616 - get_kl_loss: 0.1118 - val_loss: 0.1737 - val_get_xent_loss: 0.0625 - val_get_kl_loss: 0.1112
# Epoch 59/99
# 100000/100000 [==============================] - 11s 106us/sample - loss: 0.1736 - get_xent_loss: 0.0619 - get_kl_loss: 0.1117 - val_loss: 0.1739 - val_get_xent_loss: 0.0622 - val_get_kl_loss: 0.1117
# Epoch 60/99
# 100000/100000 [==============================] - 13s 134us/sample - loss: 0.1734 - get_xent_loss: 0.0618 - get_kl_loss: 0.1117 - val_loss: 0.1731 - val_get_xent_loss: 0.0619 - val_get_kl_loss: 0.1112
# Epoch 61/99
#  99900/100000 [============================>.] - ETA: 0s - loss: 0.1737 - get_xent_loss: 0.0618 - get_kl_loss: 0.1119
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 100000/100000 [==============================] - 11s 106us/sample - loss: 0.1737 - get_xent_loss: 0.0618 - get_kl_loss: 0.1119 - val_loss: 0.1732 - val_get_xent_loss: 0.0617 - val_get_kl_loss: 0.1115
# Epoch 62/99
# 100000/100000 [==============================] - 12s 124us/sample - loss: 0.1730 - get_xent_loss: 0.0610 - get_kl_loss: 0.1120 - val_loss: 0.1730 - val_get_xent_loss: 0.0611 - val_get_kl_loss: 0.1119
# Epoch 63/99
# 100000/100000 [==============================] - 11s 108us/sample - loss: 0.1731 - get_xent_loss: 0.0610 - get_kl_loss: 0.1121 - val_loss: 0.1729 - val_get_xent_loss: 0.0612 - val_get_kl_loss: 0.1117
# Epoch 64/99
# 100000/100000 [==============================] - 13s 127us/sample - loss: 0.1731 - get_xent_loss: 0.0611 - get_kl_loss: 0.1120 - val_loss: 0.1736 - val_get_xent_loss: 0.0620 - val_get_kl_loss: 0.1115
# Epoch 65/99
# 100000/100000 [==============================] - 13s 126us/sample - loss: 0.1730 - get_xent_loss: 0.0610 - get_kl_loss: 0.1120 - val_loss: 0.1727 - val_get_xent_loss: 0.0612 - val_get_kl_loss: 0.1115
# Epoch 66/99
# 100000/100000 [==============================] - 10s 102us/sample - loss: 0.1731 - get_xent_loss: 0.0611 - get_kl_loss: 0.1119 - val_loss: 0.1728 - val_get_xent_loss: 0.0610 - val_get_kl_loss: 0.1118
# Epoch 67/99
# 100000/100000 [==============================] - 11s 113us/sample - loss: 0.1731 - get_xent_loss: 0.0611 - get_kl_loss: 0.1120 - val_loss: 0.1731 - val_get_xent_loss: 0.0613 - val_get_kl_loss: 0.1118
# Epoch 68/99
# 100000/100000 [==============================] - 10s 104us/sample - loss: 0.1729 - get_xent_loss: 0.0609 - get_kl_loss: 0.1119 - val_loss: 0.1728 - val_get_xent_loss: 0.0612 - val_get_kl_loss: 0.1117
# Epoch 69/99
#  99700/100000 [============================>.] - ETA: 0s - loss: 0.1730 - get_xent_loss: 0.0610 - get_kl_loss: 0.1120
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 100000/100000 [==============================] - 13s 125us/sample - loss: 0.1730 - get_xent_loss: 0.0610 - get_kl_loss: 0.1120 - val_loss: 0.1735 - val_get_xent_loss: 0.0616 - val_get_kl_loss: 0.1119
# Epoch 70/99
# 100000/100000 [==============================] - 14s 142us/sample - loss: 0.1730 - get_xent_loss: 0.0609 - get_kl_loss: 0.1121 - val_loss: 0.1728 - val_get_xent_loss: 0.0610 - val_get_kl_loss: 0.1118
# Epoch 71/99
# 100000/100000 [==============================] - 10s 104us/sample - loss: 0.1730 - get_xent_loss: 0.0609 - get_kl_loss: 0.1121 - val_loss: 0.1726 - val_get_xent_loss: 0.0608 - val_get_kl_loss: 0.1118
# Epoch 72/99
# 100000/100000 [==============================] - 11s 110us/sample - loss: 0.1731 - get_xent_loss: 0.0610 - get_kl_loss: 0.1121 - val_loss: 0.1731 - val_get_xent_loss: 0.0613 - val_get_kl_loss: 0.1119
# Epoch 73/99
# 100000/100000 [==============================] - 9s 94us/sample - loss: 0.1731 - get_xent_loss: 0.0610 - get_kl_loss: 0.1121 - val_loss: 0.1724 - val_get_xent_loss: 0.0606 - val_get_kl_loss: 0.1118
# Epoch 74/99
# 100000/100000 [==============================] - 8s 83us/sample - loss: 0.1731 - get_xent_loss: 0.0610 - get_kl_loss: 0.1121 - val_loss: 0.1733 - val_get_xent_loss: 0.0615 - val_get_kl_loss: 0.1118
# Epoch 75/99
# 100000/100000 [==============================] - 10s 100us/sample - loss: 0.1732 - get_xent_loss: 0.0611 - get_kl_loss: 0.1121 - val_loss: 0.1722 - val_get_xent_loss: 0.0604 - val_get_kl_loss: 0.1118
# Epoch 76/99
# 100000/100000 [==============================] - 9s 92us/sample - loss: 0.1730 - get_xent_loss: 0.0609 - get_kl_loss: 0.1121 - val_loss: 0.1725 - val_get_xent_loss: 0.0607 - val_get_kl_loss: 0.1119
# Epoch 77/99
# 100000/100000 [==============================] - 9s 87us/sample - loss: 0.1729 - get_xent_loss: 0.0608 - get_kl_loss: 0.1121 - val_loss: 0.1727 - val_get_xent_loss: 0.0609 - val_get_kl_loss: 0.1118
# Epoch 78/99
# 100000/100000 [==============================] - 9s 88us/sample - loss: 0.1729 - get_xent_loss: 0.0609 - get_kl_loss: 0.1120 - val_loss: 0.1730 - val_get_xent_loss: 0.0612 - val_get_kl_loss: 0.1118
# Epoch 79/99
#  99800/100000 [============================>.] - ETA: 0s - loss: 0.1730 - get_xent_loss: 0.0610 - get_kl_loss: 0.1121
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 100000/100000 [==============================] - 9s 87us/sample - loss: 0.1731 - get_xent_loss: 0.0610 - get_kl_loss: 0.1121 - val_loss: 0.1728 - val_get_xent_loss: 0.0610 - val_get_kl_loss: 0.1118
# Epoch 80/99
# 100000/100000 [==============================] - 9s 89us/sample - loss: 0.1730 - get_xent_loss: 0.0609 - get_kl_loss: 0.1121 - val_loss: 0.1733 - val_get_xent_loss: 0.0614 - val_get_kl_loss: 0.1118
# Epoch 81/99
# 100000/100000 [==============================] - 9s 89us/sample - loss: 0.1728 - get_xent_loss: 0.0607 - get_kl_loss: 0.1121 - val_loss: 0.1733 - val_get_xent_loss: 0.0615 - val_get_kl_loss: 0.1118

# %%
print("Latent space encoding for beta =",beta,":")
myencoder = encoder_class(encoder)
    
plot_latent_space(myencoder,valid_data)
# Out:
# Latent space encoding for beta = 0.03 :

# %%
print("Latent space mapping for beta = ",beta,":")
plot_latent_map(myencoder,decoder,valid_data,scales = np.array([[-3,3],[-3,3]]),latent_plotrange = [-5,5])
# Out:
# Latent space mapping for beta =  0.03 :

# %%
valid_data_mat = np.tile(valid_data.reshape(len(valid_data),1,2),[1,len(valid_data),1])

# %%
train_data_mat = np.tile(train_data.reshape(len(train_data),1,2),[1,len(train_data),1])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-249-443ba2219dcb> in <module>()
# ----> 1 train_data_mat = np.tile(train_data.reshape(len(train_data),1,2),[1,len(train_data),1])
#
# <__array_function__ internals> in tile(*args, **kwargs)
#
# /home/jack/.local/lib/python3.6/site-packages/numpy/lib/shape_base.py in tile(A, reps)
#    1254         for dim_in, nrep in zip(c.shape, tup):
#    1255             if nrep != 1:
# -> 1256                 c = c.reshape(-1, n).repeat(nrep, 0)
#    1257             n //= dim_in
#    1258     return c.reshape(shape_out)
#
# MemoryError: Unable to allocate 149. GiB for an array with shape (10000000000, 2) and data type float64

# %%
distmat = np.linalg.norm(valid_data_mat - np.transpose(valid_data_mat,[1,0,2]),axis=-1)

# %%
Qs = np.logspace(-3,1,100)

# %%
numinsphere = [np.mean(np.sum(distmat<dist,axis=-1),axis=-1) for dist in Qs]

# %%
plt.plot(Qs,numinsphere)
plt.semilogx()
plt.semilogy()
plt.show()

# %%
derivative = [np.log(numinsphere[i+1]/numinsphere[i])/np.log(Qs[i+1]/Qs[i]) for i in range(len(Qs)-1)]

# %%
plt.plot(Qs[:-1],derivative)
plt.semilogx()
plt.xlabel("Q")
plt.ylabel("dim")
plt.show()

# %%
distmat.shape
# Out:
# (10000, 10000)

# %%
plt.hist(distmat.flatten(),bins = np.logspace(-4,3,20),density = True)
plt.semilogx()
plt.semilogy()
plt.show()

# %%
mymat = np.array([[[0,0],[1,1]],[[1,1]],[[0,0]]])

# %%
np.linalg.norm(mymat,axis=-1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'list' object has no attribute 'conjugate'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-252-37a90b6fda01> in <module>()
# ----> 1 np.linalg.norm(mymat,axis=-1)
#
# <__array_function__ internals> in norm(*args, **kwargs)
#
# /home/jack/.local/lib/python3.6/site-packages/numpy/linalg/linalg.py in norm(x, ord, axis, keepdims)
#    2504         elif ord is None or ord == 2:
#    2505             # special case for speedup
# -> 2506             s = (x.conj() * x).real
#    2507             return sqrt(add.reduce(s, axis=axis, keepdims=keepdims))
#    2508         else:
#
# TypeError: loop of ufunc does not support argument 0 of type list which has no callable conjugate method

# %%
np.array([[[0,0],[1,1]],[[1,1]],[[0,0]]]).shape
# Out:
# (3,)
